# %%
from torch.utils.data import DataLoader
from torch.utils.data.dataloader import default_collate
from torch.autograd import Variable
import torchvision.transforms as transforms
import torch.nn as nn

import os.path
import random
from random import uniform
import numpy as np
import torch
import torch.utils.data as data
import torchvision.transforms as transforms
import cv2
import matplotlib.pyplot as plt
import argparse
import math
os.environ['CUDA_LAUNCH_BLOCKING']='1'

# %%
## 好神秘

# %% [markdown]
# ## Data Augmentation

# %%
class Compose(object):

    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, data):
        for function_ in self.transforms:
            data = function_(data)
        return data


class Crop(object):

    def __init__(self, max_crop=0.1):
        super().__init__()
        self.max_crop = max_crop

    def __call__(self, data):
        image, label = data
        height, width = image.shape[:2]
        xmin = width
        ymin = height
        xmax = 0
        ymax = 0
        for lb in label:
            xmin = min(xmin, lb[0])
            ymin = min(ymin, lb[1])
            xmax = max(xmax, lb[2])
            ymax = max(ymax, lb[2])
        cropped_left = uniform(0, self.max_crop)
        cropped_right = uniform(0, self.max_crop)
        cropped_top = uniform(0, self.max_crop)
        cropped_bottom = uniform(0, self.max_crop)
        new_xmin = int(min(cropped_left * width, xmin))
        new_ymin = int(min(cropped_top * height, ymin))
        new_xmax = int(max(width - 1 - cropped_right * width, xmax))
        new_ymax = int(max(height - 1 - cropped_bottom * height, ymax))

        image = image[new_ymin:new_ymax, new_xmin:new_xmax, :]
        label = [[lb[0] - new_xmin, lb[1] - new_ymin, lb[2] - new_xmin, lb[3] - new_ymin, lb[4]] for lb in label]

        return image, label


class VerticalFlip(object):

    def __init__(self, prob=0.5):
        super().__init__()
        self.prob = prob

    def __call__(self, data):
        image, label = data
        if uniform(0, 1) >= self.prob:
            image = cv2.flip(image, 1)
            width = image.shape[1]
            label = [[width - lb[2], lb[1], width - lb[0], lb[3], lb[4]] for lb in label]
        return image, label


class HSVAdjust(object):

    def __init__(self, hue=30, saturation=1.5, value=1.5, prob=0.5):
        super().__init__()
        self.hue = hue
        self.saturation = saturation
        self.value = value
        self.prob = prob

    def __call__(self, data):

        def clip_hue(hue_channel):
            hue_channel[hue_channel >= 360] -= 360
            hue_channel[hue_channel < 0] += 360
            return hue_channel

        image, label = data
        adjust_hue = uniform(-self.hue, self.hue)
        adjust_saturation = uniform(1, self.saturation)
        if uniform(0, 1) >= self.prob:
            adjust_saturation = 1 / adjust_saturation
        adjust_value = uniform(1, self.value)
        if uniform(0, 1) >= self.prob:
            adjust_value = 1 / adjust_value
        image = image.astype(np.float32) / 255
        image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
        image[:, :, 0] += adjust_hue
        image[:, :, 0] = clip_hue(image[:, :, 0])
        image[:, :, 1] = np.clip(adjust_saturation * image[:, :, 1], 0.0, 1.0)
        image[:, :, 2] = np.clip(adjust_value * image[:, :, 2], 0.0, 1.0)

        image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB)
        image = (image * 255).astype(np.float32)

        return image, label


class Resize(object):

    def __init__(self, image_size):
        super().__init__()
        self.image_size = image_size

    def __call__(self, data):
        image, label = data
        height, width = image.shape[:2]
        image = cv2.resize(image, (self.image_size, self.image_size))
        width_ratio = float(self.image_size) / width
        height_ratio = float(self.image_size) / height
        new_label = []
        for lb in label:
            resized_xmin = lb[0] * width_ratio
            resized_ymin = lb[1] * height_ratio
            resized_xmax = lb[2] * width_ratio
            resized_ymax = lb[3] * height_ratio
            resize_width = resized_xmax - resized_xmin
            resize_height = resized_ymax - resized_ymin
            new_label.append([resized_xmin, resized_ymin, resize_width, resize_height, lb[4]])

        return image, new_label

# %% [markdown]
# ## Yolo dataset

# %%
class yoloDataset(data.Dataset):
    image_size = 416 # Size to be aligned

    # Parsing data list
    def __init__(self,root,list_file,train):
        self.root = root
        self.train = train
        self.fnames = []
        self.objects = [] # [x_min, y_min, x_max, y_max, class]
        self.classes = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow',
                        'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train',
                        'tvmonitor']
        self.num_classes = len(self.classes)

        with open(list_file) as f:
            lines  = f.readlines()

        # format of each line: filename (x_min, y_min, x_max, y_max, label) * object_num
        for line in lines:
            splited = line.strip().split() # .strip(): reomove space, tab from the end of each line
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            one_object = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                # int(c)+1
                one_object.append([x_min,y_min,x_max,y_max, int(c)])
            self.objects.append(one_object)
        self.num_samples = len(self.objects)

    # Getting single transformed, preprocessed image and its bounding boxes
    def __getitem__(self,idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        image_objects = self.objects[idx]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        if self.train:
            transformations = Compose([HSVAdjust(), VerticalFlip(), Crop(), Resize(self.image_size)])
        else:
            transformations = Compose([Resize(self.image_size)])

        # h,w,_ = img.shape
        # boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes)    -> replaced by batch-norm(?)
        # img = self.subMean(img,self.mean)
        # to see the whih grid is the box is located at
        # .expand_as(other): expand this tensor as other
        # [w, h, w, h] (1, 4) will be expanded to (#box, 4)
        img, image_objects = transformations((img, image_objects))
#         print(len(image_objects))

        # img.shape (416,416,3) -> (3,416,416)
        return np.transpose(np.array(img, dtype=np.float32), (2, 0, 1)), np.array(image_objects, dtype=np.float32)

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ## Yolo structure

# %%
def build_layer(in_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False, isMaxpool=False):
    if(isMaxpool):
        return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding,bias=bias),
                             nn.BatchNorm2d(out_channels),
                             nn.LeakyReLU(0.1, inplace=True),
                             nn.MaxPool2d(2,2))
    else:
        return nn.Sequential(nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding,bias=bias),
                             nn.BatchNorm2d(out_channels),
                             nn.LeakyReLU(0.1, inplace=True))

# %%
class Yolov2(nn.Module):
    def __init__(self, num_classes, 
                 anchors = [(1.3221, 1.73145), (3.19275, 4.00944), (5.05587, 8.09892), (9.47112, 4.84053),(11.2364, 10.0071)]):
        super(Yolov2,self).__init__()
        self.num_classes = num_classes
        self.anchors = anchors
        # darnet19
        self.stage1_c1 = build_layer(3, 32, 3, 1, 1, bias=False, isMaxpool=True)        
        self.stage1_c2 = build_layer(32, 64, 3, 1, 1, bias=False, isMaxpool=True)
        
        self.stage1_c3 = build_layer(64, 128, 3, 1, 1, bias=False, isMaxpool=False)        
        self.stage1_c4 = build_layer(128, 64, 1, 1, 0, bias=False, isMaxpool=False)        
        self.stage1_c5 = build_layer(64, 128, 3, 1, 1, bias=False, isMaxpool=True)  
        
        self.stage1_c6 = build_layer(128, 256, 3, 1, 1, bias=False, isMaxpool=False)        
        self.stage1_c7 = build_layer(256, 128, 1, 1, 0, bias=False, isMaxpool=False)        
        self.stage1_c8 = build_layer(128, 256, 3, 1, 1, bias=False, isMaxpool=True) 
        
        self.stage1_c9 = build_layer(256, 512, 3, 1, 1, bias=False, isMaxpool=False)        
        self.stage1_c10 = build_layer(512, 256, 1, 1, 0, bias=False, isMaxpool=False)        
        self.stage1_c11 = build_layer(256, 512, 3, 1, 1, bias=False, isMaxpool=False)        
        self.stage1_c12 = build_layer(512, 256, 1, 1, 0, bias=False, isMaxpool=False)        
        self.stage1_c13 = build_layer(256, 512, 3, 1, 1, bias=False, isMaxpool=False)
        
        self.stage2_maxpool = nn.MaxPool2d(2, 2)
        self.stage2_c1 = build_layer(512, 1024, 3, 1, 1, bias=False, isMaxpool=False)        
        self.stage2_c2 = build_layer(1024, 512, 1, 1, 0, bias=False, isMaxpool=False)        
        self.stage2_c3 = build_layer(512, 1024, 3, 1, 1, bias=False, isMaxpool=False)        
        self.stage2_c4 = build_layer(1024, 512, 1, 1, 0, bias=False, isMaxpool=False)        
        self.stage2_c5 = build_layer(512, 1024, 3, 1, 1, bias=False, isMaxpool=False)
        
        self.stage2_c6 = build_layer(1024, 1024, 3, 1, 1, bias=False, isMaxpool=False)
        self.stage2_c7 = build_layer(1024, 1024, 3, 1, 1, bias=False, isMaxpool=False)
        
        self.stage2_residual_c1 = build_layer(512, 64, 1, 1, 0, bias=False, isMaxpool=False)
        
        # classify head
        self.stage3_c1 = build_layer(256+1024, 1024, 1, 1, 0, bias=False, isMaxpool=False)
        self.stage3_c2 = nn.Conv2d(1024, len(self.anchors)*(5+self.num_classes), 1, 1, 0, bias=False)
#         self.avgpool = nn.AvgPool2d((1, 1))
#         self.softmax = nn.Softmax(dim=1)
    
    def forward(self, input):
        output_1 = self.stage1_c1(input)
        output_1 = self.stage1_c2(output_1)
        output_1 = self.stage1_c3(output_1)
        output_1 = self.stage1_c4(output_1)
        output_1 = self.stage1_c5(output_1)
        output_1 = self.stage1_c6(output_1)
        output_1 = self.stage1_c7(output_1)
        output_1 = self.stage1_c8(output_1)
        output_1 = self.stage1_c9(output_1)
        output_1 = self.stage1_c10(output_1)
        output_1 = self.stage1_c11(output_1)
        output_1 = self.stage1_c12(output_1)
        output_1 = self.stage1_c13(output_1)

        residual = output_1

        output_2 = self.stage2_maxpool(output_1)
        output_2 = self.stage2_c1(output_2)
        output_2 = self.stage2_c2(output_2)
        output_2 = self.stage2_c3(output_2)
        output_2 = self.stage2_c4(output_2)
        output_2 = self.stage2_c5(output_2)
        output_2 = self.stage2_c6(output_2)
        output_2 = self.stage2_c7(output_2)
        
        # rearrange
        output_residual = self.stage2_residual_c1(residual)
        batch_size, num_channel, height, width = output_residual.data.size()
        output_residual = output_residual.view(batch_size, int(num_channel / 4), height, 2, width, 2).contiguous()
        output_residual = output_residual.permute(0, 3, 5, 1, 2, 4).contiguous()
        output_residual = output_residual.view(batch_size, -1, int(height / 2), int(width / 2))
        
        # concate residual block
        output = torch.cat((output_2, output_residual), 1)
        output = self.stage3_c1(output)
        output = self.stage3_c2(output)
#         output = self.avgpool(output)
#         output = self.softmax(output)
        
        return output

# %%
from torchsummary import summary
model = Yolov2(20).cuda()
summary(model, (3,416,416))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 416, 416]             864
#        BatchNorm2d-2         [-1, 32, 416, 416]              64
#          LeakyReLU-3         [-1, 32, 416, 416]               0
#          MaxPool2d-4         [-1, 32, 208, 208]               0
#             Conv2d-5         [-1, 64, 208, 208]          18,432
#        BatchNorm2d-6         [-1, 64, 208, 208]             128
#          LeakyReLU-7         [-1, 64, 208, 208]               0
#          MaxPool2d-8         [-1, 64, 104, 104]               0
#             Conv2d-9        [-1, 128, 104, 104]          73,728
#       BatchNorm2d-10        [-1, 128, 104, 104]             256
#         LeakyReLU-11        [-1, 128, 104, 104]               0
#            Conv2d-12         [-1, 64, 104, 104]           8,192
#       BatchNorm2d-13         [-1, 64, 104, 104]             128
#         LeakyReLU-14         [-1, 64, 104, 104]               0
#            Conv2d-15        [-1, 128, 104, 104]          73,728
#       BatchNorm2d-16        [-1, 128, 104, 104]             256
#         LeakyReLU-17        [-1, 128, 104, 104]               0
#         MaxPool2d-18          [-1, 128, 52, 52]               0
#            Conv2d-19          [-1, 256, 52, 52]         294,912
#       BatchNorm2d-20          [-1, 256, 52, 52]             512
#         LeakyReLU-21          [-1, 256, 52, 52]               0
#            Conv2d-22          [-1, 128, 52, 52]          32,768
#       BatchNorm2d-23          [-1, 128, 52, 52]             256
#         LeakyReLU-24          [-1, 128, 52, 52]               0
#            Conv2d-25          [-1, 256, 52, 52]         294,912
#       BatchNorm2d-26          [-1, 256, 52, 52]             512
#         LeakyReLU-27          [-1, 256, 52, 52]               0
#         MaxPool2d-28          [-1, 256, 26, 26]               0
#            Conv2d-29          [-1, 512, 26, 26]       1,179,648
#       BatchNorm2d-30          [-1, 512, 26, 26]           1,024
#         LeakyReLU-31          [-1, 512, 26, 26]               0
#            Conv2d-32          [-1, 256, 26, 26]         131,072
#       BatchNorm2d-33          [-1, 256, 26, 26]             512
#         LeakyReLU-34          [-1, 256, 26, 26]               0
#            Conv2d-35          [-1, 512, 26, 26]       1,179,648
#       BatchNorm2d-36          [-1, 512, 26, 26]           1,024
#         LeakyReLU-37          [-1, 512, 26, 26]               0
#            Conv2d-38          [-1, 256, 26, 26]         131,072
#       BatchNorm2d-39          [-1, 256, 26, 26]             512
#         LeakyReLU-40          [-1, 256, 26, 26]               0
#            Conv2d-41          [-1, 512, 26, 26]       1,179,648
#       BatchNorm2d-42          [-1, 512, 26, 26]           1,024
#         LeakyReLU-43          [-1, 512, 26, 26]               0
#         MaxPool2d-44          [-1, 512, 13, 13]               0
#            Conv2d-45         [-1, 1024, 13, 13]       4,718,592
#       BatchNorm2d-46         [-1, 1024, 13, 13]           2,048
#         LeakyReLU-47         [-1, 1024, 13, 13]               0
#            Conv2d-48          [-1, 512, 13, 13]         524,288
#       BatchNorm2d-49          [-1, 512, 13, 13]           1,024
#         LeakyReLU-50          [-1, 512, 13, 13]               0
#            Conv2d-51         [-1, 1024, 13, 13]       4,718,592
#       BatchNorm2d-52         [-1, 1024, 13, 13]           2,048
#         LeakyReLU-53         [-1, 1024, 13, 13]               0
#            Conv2d-54          [-1, 512, 13, 13]         524,288
#       BatchNorm2d-55          [-1, 512, 13, 13]           1,024
#         LeakyReLU-56          [-1, 512, 13, 13]               0
#            Conv2d-57         [-1, 1024, 13, 13]       4,718,592
#       BatchNorm2d-58         [-1, 1024, 13, 13]           2,048
#         LeakyReLU-59         [-1, 1024, 13, 13]               0
#            Conv2d-60         [-1, 1024, 13, 13]       9,437,184
#       BatchNorm2d-61         [-1, 1024, 13, 13]           2,048
#         LeakyReLU-62         [-1, 1024, 13, 13]               0
#            Conv2d-63         [-1, 1024, 13, 13]       9,437,184
#       BatchNorm2d-64         [-1, 1024, 13, 13]           2,048
#         LeakyReLU-65         [-1, 1024, 13, 13]               0
#            Conv2d-66           [-1, 64, 26, 26]          32,768
#       BatchNorm2d-67           [-1, 64, 26, 26]             128
#         LeakyReLU-68           [-1, 64, 26, 26]               0
#            Conv2d-69         [-1, 1024, 13, 13]       1,310,720
#       BatchNorm2d-70         [-1, 1024, 13, 13]           2,048
#         LeakyReLU-71         [-1, 1024, 13, 13]               0
#            Conv2d-72          [-1, 125, 13, 13]         128,000
# ================================================================
# Total params: 40,169,504
# Trainable params: 40,169,504
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.98
# Forward/backward pass size (MB): 389.98
# Params size (MB): 153.23
# Estimated Total Size (MB): 545.20
# ----------------------------------------------------------------

# %% [markdown]
# ## Loss function

# %%
class YoloLoss(nn.modules.loss._Loss):
    # The loss I borrow from LightNet repo.
    def __init__(self, num_classes, anchors, reduction=32, coord_scale=1.0, noobject_scale=1.0,
                 object_scale=5.0, class_scale=1.0, thresh=0.6):
        super(YoloLoss, self).__init__()
        self.num_classes = num_classes
        self.num_anchors = len(anchors)
        self.anchor_step = len(anchors[0])
        self.anchors = torch.Tensor(anchors)
        self.reduction = reduction

        self.coord_scale = coord_scale
        self.noobject_scale = noobject_scale
        self.object_scale = object_scale
        self.class_scale = class_scale
        self.thresh = thresh

    def forward(self, output, target):

        batch_size = output.data.size(0)
        height = output.data.size(2)
        width = output.data.size(3)

        # Get x,y,w,h,conf,cls
        output = output.view(batch_size, self.num_anchors, -1, height * width)
        coord = torch.zeros_like(output[:, :, :4, :])
        coord[:, :, :2, :] = output[:, :, :2, :].sigmoid()  
        coord[:, :, 2:4, :] = output[:, :, 2:4, :]
        conf = output[:, :, 4, :].sigmoid()
        cls = output[:, :, 5:, :].contiguous().view(batch_size * self.num_anchors, self.num_classes,
                                                    height * width).transpose(1, 2).contiguous().view(-1,
                                                                                                      self.num_classes)

        # Create prediction boxes
        pred_boxes = torch.FloatTensor(batch_size * self.num_anchors * height * width, 4)
        lin_x = torch.range(0, width - 1).repeat(height, 1).view(height * width)
        lin_y = torch.range(0, height - 1).repeat(width, 1).t().contiguous().view(height * width)
        anchor_w = self.anchors[:, 0].contiguous().view(self.num_anchors, 1)
        anchor_h = self.anchors[:, 1].contiguous().view(self.num_anchors, 1)

        if torch.cuda.is_available():
            pred_boxes = pred_boxes.cuda()
            lin_x = lin_x.cuda()
            lin_y = lin_y.cuda()
            anchor_w = anchor_w.cuda()
            anchor_h = anchor_h.cuda()

        pred_boxes[:, 0] = (coord[:, :, 0].detach() + lin_x).view(-1)
        pred_boxes[:, 1] = (coord[:, :, 1].detach() + lin_y).view(-1)
        pred_boxes[:, 2] = (coord[:, :, 2].detach().exp() * anchor_w).view(-1)
        pred_boxes[:, 3] = (coord[:, :, 3].detach().exp() * anchor_h).view(-1)
        pred_boxes = pred_boxes.cpu()

        # Get target values
        coord_mask, conf_mask, cls_mask, tcoord, tconf, tcls = self.build_targets(pred_boxes, target, height, width)
        coord_mask = coord_mask.expand_as(tcoord)
        tcls = tcls[cls_mask].view(-1).long()
        cls_mask = cls_mask.view(-1, 1).repeat(1, self.num_classes)

        if torch.cuda.is_available():
            tcoord = tcoord.cuda()
            tconf = tconf.cuda()
            coord_mask = coord_mask.cuda()
            conf_mask = conf_mask.cuda()
            tcls = tcls.cuda()
            cls_mask = cls_mask.cuda()

        conf_mask = conf_mask.sqrt()
        cls = cls[cls_mask].view(-1, self.num_classes)

        # Compute losses
        mse = nn.MSELoss(size_average=False)
        ce = nn.CrossEntropyLoss(size_average=False)
        self.loss_coord = self.coord_scale * mse(coord * coord_mask, tcoord * coord_mask) / batch_size
        self.loss_conf = mse(conf * conf_mask, tconf * conf_mask) / batch_size
        self.loss_cls = self.class_scale * 2 * ce(cls, tcls) / batch_size
        self.loss_tot = self.loss_coord + self.loss_conf + self.loss_cls

        return self.loss_tot, self.loss_coord, self.loss_conf, self.loss_cls

    def build_targets(self, pred_boxes, ground_truth, height, width):
        batch_size = len(ground_truth)

        conf_mask = torch.ones(batch_size, self.num_anchors, height * width, requires_grad=False) * self.noobject_scale
        coord_mask = torch.zeros(batch_size, self.num_anchors, 1, height * width, requires_grad=False)
        cls_mask = torch.zeros(batch_size, self.num_anchors, height * width, requires_grad=False).bool()
        tcoord = torch.zeros(batch_size, self.num_anchors, 4, height * width, requires_grad=False)
        tconf = torch.zeros(batch_size, self.num_anchors, height * width, requires_grad=False)
        tcls = torch.zeros(batch_size, self.num_anchors, height * width, requires_grad=False)

        for b in range(batch_size):
            if len(ground_truth[b]) == 0:
                continue

            # Build up tensors
            cur_pred_boxes = pred_boxes[
                             b * (self.num_anchors * height * width):(b + 1) * (self.num_anchors * height * width)]
            if self.anchor_step == 4:
                anchors = self.anchors.clone()
                anchors[:, :2] = 0
            else:
                anchors = torch.cat([torch.zeros_like(self.anchors), self.anchors], 1)
            gt = torch.zeros(len(ground_truth[b]), 4)
            for i, anno in enumerate(ground_truth[b]):
                gt[i, 0] = (anno[0] + anno[2] / 2) / self.reduction
                gt[i, 1] = (anno[1] + anno[3] / 2) / self.reduction
                gt[i, 2] = anno[2] / self.reduction
                gt[i, 3] = anno[3] / self.reduction

            # Set confidence mask of matching detections to 0
            iou_gt_pred = bbox_ious(gt, cur_pred_boxes)
            mask = (iou_gt_pred > self.thresh).sum(0) >= 1
            conf_mask[b][mask.view_as(conf_mask[b])] = 0

            # Find best anchor for each ground truth
            gt_wh = gt.clone()
            gt_wh[:, :2] = 0
            iou_gt_anchors = bbox_ious(gt_wh, anchors)
            _, best_anchors = iou_gt_anchors.max(1)

            # Set masks and target values for each ground truth
            for i, anno in enumerate(ground_truth[b]):
                gi = min(width - 1, max(0, int(gt[i, 0])))
                gj = min(height - 1, max(0, int(gt[i, 1])))
                best_n = best_anchors[i]
                iou = iou_gt_pred[i][best_n * height * width + gj * width + gi]
                coord_mask[b][best_n][0][gj * width + gi] = 1
                cls_mask[b][best_n][gj * width + gi] = 1
                conf_mask[b][best_n][gj * width + gi] = self.object_scale
                tcoord[b][best_n][0][gj * width + gi] = gt[i, 0] - gi
                tcoord[b][best_n][1][gj * width + gi] = gt[i, 1] - gj
                tcoord[b][best_n][2][gj * width + gi] = math.log(max(gt[i, 2], 1.0) / self.anchors[best_n, 0])
                tcoord[b][best_n][3][gj * width + gi] = math.log(max(gt[i, 3], 1.0) / self.anchors[best_n, 1])
                tconf[b][best_n][gj * width + gi] = iou
                tcls[b][best_n][gj * width + gi] = int(anno[4])

        return coord_mask, conf_mask, cls_mask, tcoord, tconf, tcls


def bbox_ious(boxes1, boxes2):
    b1x1, b1y1 = (boxes1[:, :2] - (boxes1[:, 2:4] / 2)).split(1, 1)
    b1x2, b1y2 = (boxes1[:, :2] + (boxes1[:, 2:4] / 2)).split(1, 1)
    b2x1, b2y1 = (boxes2[:, :2] - (boxes2[:, 2:4] / 2)).split(1, 1)
    b2x2, b2y2 = (boxes2[:, :2] + (boxes2[:, 2:4] / 2)).split(1, 1)

    dx = (b1x2.min(b2x2.t()) - b1x1.max(b2x1.t())).clamp(min=0)
    dy = (b1y2.min(b2y2.t()) - b1y1.max(b2y1.t())).clamp(min=0)
    intersections = dx * dy

    areas1 = (b1x2 - b1x1) * (b1y2 - b1y1)
    areas2 = (b2x2 - b2x1) * (b2y2 - b2y1)
    unions = (areas1 + areas2.t()) - intersections

    return intersections / unions

# %%
def custom_collate_fn(batch):
    items = list(zip(*batch))
    items[0] = default_collate(items[0])
    items[1] = list(items[1])
    return items

# %% [markdown]
# ## Train

# %%
batch_size = 8
root = 'VOCdevkit/VOC2007/JPEGImages/'
reduction = 32
momentum = 0.9
decay = 0.001
valid_interval = 10
epoches = 100
epoch_patience = 20
pre_trained_model_path = 'yolov2.weights'
es_min_delta = 0.0

def train():
    # check cuda
    if torch.cuda.is_available():
        torch.cuda.manual_seed(123)
    else:
        torch.manual_seed(123)
        
    # set scheduler
    learning_rate_schedule = {"0": 1e-5, "5": 1e-4, "80": 1e-5, "110": 1e-6}
#     learning_rate_schedule = {"0": 1e-5, "5": 1e-4, "30": 1e-5, "45": 1e-6}
    
    # read data
    train_params = {"batch_size": batch_size,
                       "shuffle": True,
                       "drop_last": True,
                   "collate_fn": custom_collate_fn}

    valid_params = {"batch_size": batch_size,
                   "shuffle": False,
                   "drop_last": False,
                   "collate_fn": custom_collate_fn}
    
    train_set = yoloDataset(root, root+'voc2007train.txt',train=True)
    train_generator = DataLoader(train_set, **train_params)

    valid_set = yoloDataset(root, root+'voc2007valid.txt',train=False)
    valid_generator = DataLoader(valid_set, **valid_params)
    
    # load pretrain weight
    if torch.cuda.is_available():
        model = Yolov2(train_set.num_classes)
#         model.load_state_dict(torch.load(pre_trained_model_path))
    else:
        model = Yolov2(train_set.num_classes)
#         model.load_state_dict(torch.load(pre_trained_model_path, map_location=lambda storage, loc: storage))
    # The following line will re-initialize weight for the last layer, which is useful
    # when you want to retrain the model based on my trained weights. if you uncomment it,
    # you will see the loss is already very small at the beginning.
#     nn.init.normal_(list(model.modules())[-1].weight, 0, 0.01)
    
    if torch.cuda.is_available():
        model.cuda()

    criterion = YoloLoss(train_set.num_classes, model.anchors, reduction)
    optimizer = torch.optim.SGD(model.parameters(), lr=1e-5, momentum=momentum, weight_decay=decay)
    best_loss = 1e10
    best_epoch = 0
    
    # start train and valid
    num_iter_per_epoch = len(train_generator)
    for epoch in range(epoches):
        # scheduler change learning rate
        if str(epoch) in learning_rate_schedule.keys():
            for param_group in optimizer.param_groups:
                param_group['lr'] = learning_rate_schedule[str(epoch)]
                
        # batch train
        model.train()
        for iter, batch in enumerate(train_generator):
            image, label = batch
            if torch.cuda.is_available():
                image = Variable(image.cuda(), requires_grad=True)
            else:
                image = Variable(image, requires_grad=True)
            optimizer.zero_grad()
            logits = model(image)
            loss, loss_coord, loss_conf, loss_cls = criterion(logits, label)
            loss.backward()
            optimizer.step()
            print("Train Epoch: {}/{}, Iteration: {}/{}, Lr: {}, Loss:{:.2f} (Coord:{:.2f} Conf:{:.2f} Cls:{:.2f})".format(
                epoch + 1,
                epoches,
                iter + 1,
                num_iter_per_epoch,
                optimizer.param_groups[0]['lr'],
                loss,
                loss_coord,
                loss_conf,
                loss_cls))
        
        # valid
        model.eval()
        loss_ls = []
        loss_coord_ls = []
        loss_conf_ls = []
        loss_cls_ls = []
        for valid_iter, valid_batch in enumerate(valid_generator):
            valid_image, valid_label = valid_batch
            num_sample = len(valid_label)

            if torch.cuda.is_available():
                valid_image = valid_image.cuda()

            with torch.no_grad():
                valid_logits = model(valid_image)
                batch_loss, batch_loss_coord, batch_loss_conf, batch_loss_cls = criterion(valid_logits, valid_label)
            # record loss
            loss_ls.append(batch_loss * num_sample)
            loss_coord_ls.append(batch_loss_coord * num_sample)
            loss_conf_ls.append(batch_loss_conf * num_sample)
            loss_cls_ls.append(batch_loss_cls * num_sample)

        valid_loss = sum(loss_ls) / valid_set.__len__()
        valid_coord_loss = sum(loss_coord_ls) / valid_set.__len__()
        valid_conf_loss = sum(loss_conf_ls) / valid_set.__len__()
        valid_cls_loss = sum(loss_cls_ls) / valid_set.__len__()
        print("\nTest Epoch: {}/{}, Lr: {}, Loss:{:.2f} (Coord:{:.2f} Conf:{:.2f} Cls:{:.2f})\n".format(
            epoch + 1,
            epoches,
            optimizer.param_groups[0]['lr'],
            valid_loss,
            valid_coord_loss,
            valid_conf_loss,
            valid_cls_loss))
            
        # save the best model weight
        if valid_loss + es_min_delta < best_loss:
            best_loss = valid_loss
            best_epoch = epoch
            torch.save(model.state_dict(), os.path.join('model_best_v2.pth'))

        # Early stopping
        if epoch - best_epoch > epoch_patience > 0:
            print("Stop training at epoch {}. The lowest loss achieved is {}".format(epoch, valid_loss))
            break

# %%
train()
# Out:
# /tmp/ipykernel_431703/3533180086.py:36: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   lin_x = torch.range(0, width - 1).repeat(height, 1).view(height * width)
# /tmp/ipykernel_431703/3533180086.py:37: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   lin_y = torch.range(0, height - 1).repeat(width, 1).t().contiguous().view(height * width)
# /home/andrea/anaconda3/envs/Lab_env/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train Epoch: 1/100, Iteration: 1/438, Lr: 1e-05, Loss:256.85 (Coord:2.98 Conf:234.36 Cls:19.51)
# Train Epoch: 1/100, Iteration: 2/438, Lr: 1e-05, Loss:242.96 (Coord:2.35 Conf:226.41 Cls:14.19)
# Train Epoch: 1/100, Iteration: 3/438, Lr: 1e-05, Loss:218.44 (Coord:1.49 Conf:206.28 Cls:10.67)
# Train Epoch: 1/100, Iteration: 4/438, Lr: 1e-05, Loss:196.61 (Coord:2.51 Conf:181.13 Cls:12.98)
# Train Epoch: 1/100, Iteration: 5/438, Lr: 1e-05, Loss:167.74 (Coord:1.78 Conf:154.43 Cls:11.52)
# Train Epoch: 1/100, Iteration: 6/438, Lr: 1e-05, Loss:143.15 (Coord:2.03 Conf:124.12 Cls:17.00)
# Train Epoch: 1/100, Iteration: 7/438, Lr: 1e-05, Loss:115.87 (Coord:1.80 Conf:99.77 Cls:14.30)
# Train Epoch: 1/100, Iteration: 8/438, Lr: 1e-05, Loss:103.82 (Coord:3.08 Conf:74.59 Cls:26.15)
# Train Epoch: 1/100, Iteration: 9/438, Lr: 1e-05, Loss:70.24 (Coord:1.51 Conf:56.30 Cls:12.43)
# Train Epoch: 1/100, Iteration: 10/438, Lr: 1e-05, Loss:64.59 (Coord:2.47 Conf:40.94 Cls:21.18)
# Train Epoch: 1/100, Iteration: 11/438, Lr: 1e-05, Loss:49.67 (Coord:2.49 Conf:31.13 Cls:16.05)
# Train Epoch: 1/100, Iteration: 12/438, Lr: 1e-05, Loss:35.67 (Coord:1.59 Conf:22.53 Cls:11.54)
# Train Epoch: 1/100, Iteration: 13/438, Lr: 1e-05, Loss:37.45 (Coord:2.27 Conf:17.56 Cls:17.62)
# Train Epoch: 1/100, Iteration: 14/438, Lr: 1e-05, Loss:36.75 (Coord:1.98 Conf:14.92 Cls:19.85)
# Train Epoch: 1/100, Iteration: 15/438, Lr: 1e-05, Loss:22.58 (Coord:1.80 Conf:10.66 Cls:10.13)
# Train Epoch: 1/100, Iteration: 16/438, Lr: 1e-05, Loss:29.05 (Coord:1.98 Conf:8.89 Cls:18.18)
# Train Epoch: 1/100, Iteration: 17/438, Lr: 1e-05, Loss:20.72 (Coord:1.04 Conf:7.72 Cls:11.97)
# Train Epoch: 1/100, Iteration: 18/438, Lr: 1e-05, Loss:17.58 (Coord:1.78 Conf:5.32 Cls:10.48)
# Train Epoch: 1/100, Iteration: 19/438, Lr: 1e-05, Loss:27.38 (Coord:2.85 Conf:5.75 Cls:18.78)
# Train Epoch: 1/100, Iteration: 20/438, Lr: 1e-05, Loss:22.39 (Coord:2.23 Conf:4.68 Cls:15.49)
# Train Epoch: 1/100, Iteration: 21/438, Lr: 1e-05, Loss:21.74 (Coord:1.86 Conf:5.64 Cls:14.25)
# Train Epoch: 1/100, Iteration: 22/438, Lr: 1e-05, Loss:19.03 (Coord:1.84 Conf:4.57 Cls:12.62)
# Train Epoch: 1/100, Iteration: 23/438, Lr: 1e-05, Loss:22.00 (Coord:2.14 Conf:4.27 Cls:15.59)
# Train Epoch: 1/100, Iteration: 24/438, Lr: 1e-05, Loss:25.21 (Coord:2.61 Conf:4.39 Cls:18.20)
# Train Epoch: 1/100, Iteration: 25/438, Lr: 1e-05, Loss:23.85 (Coord:2.20 Conf:4.48 Cls:17.18)
# Train Epoch: 1/100, Iteration: 26/438, Lr: 1e-05, Loss:29.34 (Coord:3.18 Conf:4.01 Cls:22.16)
# Train Epoch: 1/100, Iteration: 27/438, Lr: 1e-05, Loss:28.08 (Coord:1.83 Conf:4.69 Cls:21.56)
# Train Epoch: 1/100, Iteration: 28/438, Lr: 1e-05, Loss:20.71 (Coord:2.14 Conf:3.09 Cls:15.48)
# Train Epoch: 1/100, Iteration: 29/438, Lr: 1e-05, Loss:18.83 (Coord:1.03 Conf:4.11 Cls:13.69)
# Train Epoch: 1/100, Iteration: 30/438, Lr: 1e-05, Loss:19.66 (Coord:1.61 Conf:3.29 Cls:14.77)
# Train Epoch: 1/100, Iteration: 31/438, Lr: 1e-05, Loss:28.10 (Coord:2.74 Conf:3.93 Cls:21.42)
# Train Epoch: 1/100, Iteration: 32/438, Lr: 1e-05, Loss:14.51 (Coord:1.14 Conf:2.93 Cls:10.45)
# Train Epoch: 1/100, Iteration: 33/438, Lr: 1e-05, Loss:17.96 (Coord:1.32 Conf:3.35 Cls:13.29)
# Train Epoch: 1/100, Iteration: 34/438, Lr: 1e-05, Loss:38.82 (Coord:4.27 Conf:4.63 Cls:29.92)
# Train Epoch: 1/100, Iteration: 35/438, Lr: 1e-05, Loss:25.42 (Coord:1.76 Conf:4.35 Cls:19.31)
# Train Epoch: 1/100, Iteration: 36/438, Lr: 1e-05, Loss:18.41 (Coord:1.31 Conf:3.49 Cls:13.61)
# Train Epoch: 1/100, Iteration: 37/438, Lr: 1e-05, Loss:14.98 (Coord:1.44 Conf:2.84 Cls:10.70)
# Train Epoch: 1/100, Iteration: 38/438, Lr: 1e-05, Loss:20.09 (Coord:2.14 Conf:2.86 Cls:15.09)
# Train Epoch: 1/100, Iteration: 39/438, Lr: 1e-05, Loss:15.38 (Coord:0.91 Conf:3.35 Cls:11.13)
# Train Epoch: 1/100, Iteration: 40/438, Lr: 1e-05, Loss:18.96 (Coord:1.84 Conf:3.11 Cls:14.00)
# Train Epoch: 1/100, Iteration: 41/438, Lr: 1e-05, Loss:13.08 (Coord:1.12 Conf:2.49 Cls:9.47)
# Train Epoch: 1/100, Iteration: 42/438, Lr: 1e-05, Loss:15.65 (Coord:0.88 Conf:3.16 Cls:11.61)
# Train Epoch: 1/100, Iteration: 43/438, Lr: 1e-05, Loss:45.35 (Coord:4.32 Conf:5.69 Cls:35.35)
# Train Epoch: 1/100, Iteration: 44/438, Lr: 1e-05, Loss:38.55 (Coord:3.72 Conf:4.43 Cls:30.41)
# Train Epoch: 1/100, Iteration: 45/438, Lr: 1e-05, Loss:20.23 (Coord:1.78 Conf:3.77 Cls:14.68)
# Train Epoch: 1/100, Iteration: 46/438, Lr: 1e-05, Loss:30.17 (Coord:2.69 Conf:4.76 Cls:22.72)
# Train Epoch: 1/100, Iteration: 47/438, Lr: 1e-05, Loss:14.75 (Coord:1.07 Conf:2.70 Cls:10.97)
# Train Epoch: 1/100, Iteration: 48/438, Lr: 1e-05, Loss:22.85 (Coord:1.82 Conf:3.93 Cls:17.11)
# Train Epoch: 1/100, Iteration: 49/438, Lr: 1e-05, Loss:34.89 (Coord:3.43 Conf:4.98 Cls:26.48)
# Train Epoch: 1/100, Iteration: 50/438, Lr: 1e-05, Loss:19.08 (Coord:1.66 Conf:3.28 Cls:14.14)
# Train Epoch: 1/100, Iteration: 51/438, Lr: 1e-05, Loss:24.91 (Coord:2.22 Conf:3.44 Cls:19.25)
# Train Epoch: 1/100, Iteration: 52/438, Lr: 1e-05, Loss:19.17 (Coord:1.97 Conf:2.45 Cls:14.75)
# Train Epoch: 1/100, Iteration: 53/438, Lr: 1e-05, Loss:21.31 (Coord:1.88 Conf:2.90 Cls:16.53)
# Train Epoch: 1/100, Iteration: 54/438, Lr: 1e-05, Loss:15.83 (Coord:1.40 Conf:2.65 Cls:11.77)
# Train Epoch: 1/100, Iteration: 55/438, Lr: 1e-05, Loss:21.64 (Coord:1.97 Conf:3.52 Cls:16.15)
# Train Epoch: 1/100, Iteration: 56/438, Lr: 1e-05, Loss:14.88 (Coord:1.23 Conf:2.95 Cls:10.70)
# Train Epoch: 1/100, Iteration: 57/438, Lr: 1e-05, Loss:24.01 (Coord:2.31 Conf:3.68 Cls:18.02)
# Train Epoch: 1/100, Iteration: 58/438, Lr: 1e-05, Loss:14.39 (Coord:1.27 Conf:2.77 Cls:10.35)
# Train Epoch: 1/100, Iteration: 59/438, Lr: 1e-05, Loss:25.63 (Coord:2.06 Conf:4.50 Cls:19.06)
# Train Epoch: 1/100, Iteration: 60/438, Lr: 1e-05, Loss:17.05 (Coord:1.50 Conf:2.46 Cls:13.09)
# Train Epoch: 1/100, Iteration: 61/438, Lr: 1e-05, Loss:18.81 (Coord:1.97 Conf:3.29 Cls:13.55)
# Train Epoch: 1/100, Iteration: 62/438, Lr: 1e-05, Loss:15.24 (Coord:1.43 Conf:2.62 Cls:11.20)
# Train Epoch: 1/100, Iteration: 63/438, Lr: 1e-05, Loss:18.17 (Coord:1.34 Conf:3.28 Cls:13.55)
# Train Epoch: 1/100, Iteration: 64/438, Lr: 1e-05, Loss:10.65 (Coord:0.81 Conf:1.98 Cls:7.86)
# Train Epoch: 1/100, Iteration: 65/438, Lr: 1e-05, Loss:30.90 (Coord:3.90 Conf:2.82 Cls:24.19)
# Train Epoch: 1/100, Iteration: 66/438, Lr: 1e-05, Loss:17.47 (Coord:1.28 Conf:2.91 Cls:13.28)
# Train Epoch: 1/100, Iteration: 67/438, Lr: 1e-05, Loss:10.78 (Coord:0.62 Conf:2.31 Cls:7.85)
# Train Epoch: 1/100, Iteration: 68/438, Lr: 1e-05, Loss:20.59 (Coord:1.75 Conf:3.86 Cls:14.98)
# Train Epoch: 1/100, Iteration: 69/438, Lr: 1e-05, Loss:15.92 (Coord:1.02 Conf:3.05 Cls:11.85)
# Train Epoch: 1/100, Iteration: 70/438, Lr: 1e-05, Loss:15.55 (Coord:1.07 Conf:2.47 Cls:12.01)
# Train Epoch: 1/100, Iteration: 71/438, Lr: 1e-05, Loss:12.98 (Coord:0.88 Conf:2.76 Cls:9.34)
# Train Epoch: 1/100, Iteration: 72/438, Lr: 1e-05, Loss:24.21 (Coord:2.17 Conf:3.95 Cls:18.09)
# Train Epoch: 1/100, Iteration: 73/438, Lr: 1e-05, Loss:23.49 (Coord:1.89 Conf:4.34 Cls:17.26)
# Train Epoch: 1/100, Iteration: 74/438, Lr: 1e-05, Loss:20.36 (Coord:2.20 Conf:3.14 Cls:15.02)
# Train Epoch: 1/100, Iteration: 75/438, Lr: 1e-05, Loss:19.42 (Coord:1.58 Conf:3.96 Cls:13.87)
# Train Epoch: 1/100, Iteration: 76/438, Lr: 1e-05, Loss:13.58 (Coord:1.19 Conf:2.35 Cls:10.04)
# Train Epoch: 1/100, Iteration: 77/438, Lr: 1e-05, Loss:12.68 (Coord:0.91 Conf:2.76 Cls:9.01)
# Train Epoch: 1/100, Iteration: 78/438, Lr: 1e-05, Loss:14.92 (Coord:1.74 Conf:2.95 Cls:10.22)
# Train Epoch: 1/100, Iteration: 79/438, Lr: 1e-05, Loss:29.38 (Coord:2.76 Conf:5.11 Cls:21.50)
# Train Epoch: 1/100, Iteration: 80/438, Lr: 1e-05, Loss:15.38 (Coord:1.23 Conf:2.54 Cls:11.61)
# Train Epoch: 1/100, Iteration: 81/438, Lr: 1e-05, Loss:28.35 (Coord:2.23 Conf:5.03 Cls:21.10)
# Train Epoch: 1/100, Iteration: 82/438, Lr: 1e-05, Loss:12.83 (Coord:1.16 Conf:2.28 Cls:9.39)
# Train Epoch: 1/100, Iteration: 83/438, Lr: 1e-05, Loss:20.09 (Coord:1.29 Conf:3.74 Cls:15.06)
# Train Epoch: 1/100, Iteration: 84/438, Lr: 1e-05, Loss:21.11 (Coord:2.00 Conf:3.58 Cls:15.52)
# Train Epoch: 1/100, Iteration: 85/438, Lr: 1e-05, Loss:21.03 (Coord:1.52 Conf:4.04 Cls:15.46)
# Train Epoch: 1/100, Iteration: 86/438, Lr: 1e-05, Loss:15.12 (Coord:1.11 Conf:3.00 Cls:11.01)
# Train Epoch: 1/100, Iteration: 87/438, Lr: 1e-05, Loss:17.17 (Coord:1.51 Conf:2.88 Cls:12.77)
# Train Epoch: 1/100, Iteration: 88/438, Lr: 1e-05, Loss:19.02 (Coord:2.18 Conf:2.78 Cls:14.06)
# Train Epoch: 1/100, Iteration: 89/438, Lr: 1e-05, Loss:15.80 (Coord:1.11 Conf:2.62 Cls:12.06)
# Train Epoch: 1/100, Iteration: 90/438, Lr: 1e-05, Loss:28.89 (Coord:2.77 Conf:4.57 Cls:21.55)
# Train Epoch: 1/100, Iteration: 91/438, Lr: 1e-05, Loss:13.05 (Coord:1.08 Conf:2.03 Cls:9.94)
# Train Epoch: 1/100, Iteration: 92/438, Lr: 1e-05, Loss:20.57 (Coord:1.67 Conf:3.88 Cls:15.02)
# Train Epoch: 1/100, Iteration: 93/438, Lr: 1e-05, Loss:12.43 (Coord:1.07 Conf:2.91 Cls:8.45)
# Train Epoch: 1/100, Iteration: 94/438, Lr: 1e-05, Loss:15.68 (Coord:1.22 Conf:3.16 Cls:11.30)
# Train Epoch: 1/100, Iteration: 95/438, Lr: 1e-05, Loss:20.39 (Coord:2.41 Conf:3.10 Cls:14.87)
# Train Epoch: 1/100, Iteration: 96/438, Lr: 1e-05, Loss:22.46 (Coord:2.64 Conf:3.27 Cls:16.56)
# Train Epoch: 1/100, Iteration: 97/438, Lr: 1e-05, Loss:22.02 (Coord:1.90 Conf:3.99 Cls:16.13)
# Train Epoch: 1/100, Iteration: 98/438, Lr: 1e-05, Loss:13.03 (Coord:0.79 Conf:2.99 Cls:9.24)
# Train Epoch: 1/100, Iteration: 99/438, Lr: 1e-05, Loss:12.77 (Coord:1.34 Conf:2.32 Cls:9.11)
# Train Epoch: 1/100, Iteration: 100/438, Lr: 1e-05, Loss:28.78 (Coord:1.91 Conf:6.15 Cls:20.71)
# Train Epoch: 1/100, Iteration: 101/438, Lr: 1e-05, Loss:17.63 (Coord:1.29 Conf:2.57 Cls:13.76)
# Train Epoch: 1/100, Iteration: 102/438, Lr: 1e-05, Loss:33.49 (Coord:3.30 Conf:4.69 Cls:25.50)
# Train Epoch: 1/100, Iteration: 103/438, Lr: 1e-05, Loss:14.69 (Coord:1.06 Conf:2.36 Cls:11.26)
# Train Epoch: 1/100, Iteration: 104/438, Lr: 1e-05, Loss:20.87 (Coord:3.10 Conf:2.58 Cls:15.19)
# Train Epoch: 1/100, Iteration: 105/438, Lr: 1e-05, Loss:15.32 (Coord:1.18 Conf:3.06 Cls:11.07)
# Train Epoch: 1/100, Iteration: 106/438, Lr: 1e-05, Loss:15.53 (Coord:1.38 Conf:2.81 Cls:11.34)
# Train Epoch: 1/100, Iteration: 107/438, Lr: 1e-05, Loss:19.68 (Coord:1.64 Conf:3.34 Cls:14.70)
# Train Epoch: 1/100, Iteration: 108/438, Lr: 1e-05, Loss:19.73 (Coord:1.64 Conf:2.67 Cls:15.42)
# Train Epoch: 1/100, Iteration: 109/438, Lr: 1e-05, Loss:20.69 (Coord:2.39 Conf:2.42 Cls:15.88)
# Train Epoch: 1/100, Iteration: 110/438, Lr: 1e-05, Loss:16.75 (Coord:1.29 Conf:2.83 Cls:12.62)
# Train Epoch: 1/100, Iteration: 111/438, Lr: 1e-05, Loss:12.74 (Coord:1.06 Conf:2.31 Cls:9.37)
# Train Epoch: 1/100, Iteration: 112/438, Lr: 1e-05, Loss:16.52 (Coord:0.89 Conf:3.83 Cls:11.80)
# Train Epoch: 1/100, Iteration: 113/438, Lr: 1e-05, Loss:17.73 (Coord:1.47 Conf:3.58 Cls:12.68)
# Train Epoch: 1/100, Iteration: 114/438, Lr: 1e-05, Loss:19.21 (Coord:1.59 Conf:3.41 Cls:14.21)
# Train Epoch: 1/100, Iteration: 115/438, Lr: 1e-05, Loss:16.57 (Coord:1.43 Conf:3.22 Cls:11.92)
# Train Epoch: 1/100, Iteration: 116/438, Lr: 1e-05, Loss:21.22 (Coord:2.02 Conf:3.63 Cls:15.58)
# Train Epoch: 1/100, Iteration: 117/438, Lr: 1e-05, Loss:16.29 (Coord:1.33 Conf:3.14 Cls:11.82)
# Train Epoch: 1/100, Iteration: 118/438, Lr: 1e-05, Loss:15.41 (Coord:0.86 Conf:3.48 Cls:11.07)
# Train Epoch: 1/100, Iteration: 119/438, Lr: 1e-05, Loss:22.59 (Coord:1.71 Conf:4.39 Cls:16.49)
# Train Epoch: 1/100, Iteration: 120/438, Lr: 1e-05, Loss:21.27 (Coord:2.24 Conf:3.86 Cls:15.16)
# Train Epoch: 1/100, Iteration: 121/438, Lr: 1e-05, Loss:15.39 (Coord:1.12 Conf:3.08 Cls:11.19)
# Train Epoch: 1/100, Iteration: 122/438, Lr: 1e-05, Loss:12.65 (Coord:1.11 Conf:2.22 Cls:9.32)
# Train Epoch: 1/100, Iteration: 123/438, Lr: 1e-05, Loss:11.97 (Coord:0.87 Conf:2.65 Cls:8.44)
# Train Epoch: 1/100, Iteration: 124/438, Lr: 1e-05, Loss:31.63 (Coord:3.77 Conf:4.69 Cls:23.18)
# Train Epoch: 1/100, Iteration: 125/438, Lr: 1e-05, Loss:12.30 (Coord:1.11 Conf:2.80 Cls:8.39)
# Train Epoch: 1/100, Iteration: 126/438, Lr: 1e-05, Loss:21.65 (Coord:1.90 Conf:3.49 Cls:16.27)
# Train Epoch: 1/100, Iteration: 127/438, Lr: 1e-05, Loss:17.41 (Coord:1.98 Conf:3.28 Cls:12.16)
# Train Epoch: 1/100, Iteration: 128/438, Lr: 1e-05, Loss:17.04 (Coord:1.57 Conf:2.45 Cls:13.02)
# Train Epoch: 1/100, Iteration: 129/438, Lr: 1e-05, Loss:13.57 (Coord:1.60 Conf:2.17 Cls:9.80)
# Train Epoch: 1/100, Iteration: 130/438, Lr: 1e-05, Loss:13.76 (Coord:0.91 Conf:2.84 Cls:10.02)
# Train Epoch: 1/100, Iteration: 131/438, Lr: 1e-05, Loss:25.11 (Coord:2.14 Conf:4.11 Cls:18.86)
# Train Epoch: 1/100, Iteration: 132/438, Lr: 1e-05, Loss:17.64 (Coord:1.41 Conf:3.41 Cls:12.82)
# Train Epoch: 1/100, Iteration: 133/438, Lr: 1e-05, Loss:15.64 (Coord:1.66 Conf:2.63 Cls:11.35)
# Train Epoch: 1/100, Iteration: 134/438, Lr: 1e-05, Loss:18.16 (Coord:1.78 Conf:3.59 Cls:12.80)
# Train Epoch: 1/100, Iteration: 135/438, Lr: 1e-05, Loss:27.97 (Coord:2.32 Conf:5.39 Cls:20.26)
# Train Epoch: 1/100, Iteration: 136/438, Lr: 1e-05, Loss:28.33 (Coord:1.68 Conf:5.63 Cls:21.02)
# Train Epoch: 1/100, Iteration: 137/438, Lr: 1e-05, Loss:16.67 (Coord:1.83 Conf:2.57 Cls:12.26)
# Train Epoch: 1/100, Iteration: 138/438, Lr: 1e-05, Loss:19.12 (Coord:2.52 Conf:3.20 Cls:13.40)
# Train Epoch: 1/100, Iteration: 139/438, Lr: 1e-05, Loss:12.84 (Coord:1.12 Conf:2.48 Cls:9.24)
# Train Epoch: 1/100, Iteration: 140/438, Lr: 1e-05, Loss:17.00 (Coord:1.51 Conf:3.29 Cls:12.20)
# Train Epoch: 1/100, Iteration: 141/438, Lr: 1e-05, Loss:20.49 (Coord:2.17 Conf:3.64 Cls:14.67)
# Train Epoch: 1/100, Iteration: 142/438, Lr: 1e-05, Loss:27.16 (Coord:2.46 Conf:3.65 Cls:21.05)
# Train Epoch: 1/100, Iteration: 143/438, Lr: 1e-05, Loss:16.56 (Coord:1.47 Conf:2.87 Cls:12.22)
# Train Epoch: 1/100, Iteration: 144/438, Lr: 1e-05, Loss:20.63 (Coord:1.76 Conf:3.83 Cls:15.03)
# Train Epoch: 1/100, Iteration: 145/438, Lr: 1e-05, Loss:23.37 (Coord:1.81 Conf:3.93 Cls:17.63)
# Train Epoch: 1/100, Iteration: 146/438, Lr: 1e-05, Loss:15.96 (Coord:1.46 Conf:3.34 Cls:11.17)
# Train Epoch: 1/100, Iteration: 147/438, Lr: 1e-05, Loss:21.69 (Coord:1.70 Conf:3.56 Cls:16.43)
# Train Epoch: 1/100, Iteration: 148/438, Lr: 1e-05, Loss:23.28 (Coord:2.28 Conf:3.49 Cls:17.51)
# Train Epoch: 1/100, Iteration: 149/438, Lr: 1e-05, Loss:15.58 (Coord:1.57 Conf:2.39 Cls:11.62)
# Train Epoch: 1/100, Iteration: 150/438, Lr: 1e-05, Loss:37.61 (Coord:2.57 Conf:4.82 Cls:30.22)
# Train Epoch: 1/100, Iteration: 151/438, Lr: 1e-05, Loss:15.54 (Coord:1.21 Conf:3.98 Cls:10.35)
# Train Epoch: 1/100, Iteration: 152/438, Lr: 1e-05, Loss:16.85 (Coord:1.41 Conf:3.49 Cls:11.95)
# Train Epoch: 1/100, Iteration: 153/438, Lr: 1e-05, Loss:17.86 (Coord:1.51 Conf:4.21 Cls:12.14)
# Train Epoch: 1/100, Iteration: 154/438, Lr: 1e-05, Loss:15.67 (Coord:1.78 Conf:2.58 Cls:11.30)
# Train Epoch: 1/100, Iteration: 155/438, Lr: 1e-05, Loss:12.02 (Coord:0.83 Conf:2.82 Cls:8.38)
# Train Epoch: 1/100, Iteration: 156/438, Lr: 1e-05, Loss:12.88 (Coord:1.25 Conf:1.85 Cls:9.78)
# Train Epoch: 1/100, Iteration: 157/438, Lr: 1e-05, Loss:14.49 (Coord:0.91 Conf:3.24 Cls:10.34)
# Train Epoch: 1/100, Iteration: 158/438, Lr: 1e-05, Loss:12.80 (Coord:1.57 Conf:2.32 Cls:8.90)
# Train Epoch: 1/100, Iteration: 159/438, Lr: 1e-05, Loss:34.40 (Coord:3.85 Conf:4.93 Cls:25.62)
# Train Epoch: 1/100, Iteration: 160/438, Lr: 1e-05, Loss:14.30 (Coord:0.89 Conf:2.57 Cls:10.85)
# Train Epoch: 1/100, Iteration: 161/438, Lr: 1e-05, Loss:16.23 (Coord:2.06 Conf:2.80 Cls:11.36)
# Train Epoch: 1/100, Iteration: 162/438, Lr: 1e-05, Loss:10.42 (Coord:1.04 Conf:2.01 Cls:7.37)
# Train Epoch: 1/100, Iteration: 163/438, Lr: 1e-05, Loss:12.70 (Coord:1.33 Conf:2.15 Cls:9.22)
# Train Epoch: 1/100, Iteration: 164/438, Lr: 1e-05, Loss:17.26 (Coord:1.54 Conf:3.25 Cls:12.47)
# Train Epoch: 1/100, Iteration: 165/438, Lr: 1e-05, Loss:24.35 (Coord:2.65 Conf:4.09 Cls:17.61)
# Train Epoch: 1/100, Iteration: 166/438, Lr: 1e-05, Loss:24.97 (Coord:2.28 Conf:3.74 Cls:18.94)
# Train Epoch: 1/100, Iteration: 167/438, Lr: 1e-05, Loss:22.86 (Coord:1.64 Conf:4.66 Cls:16.56)
# Train Epoch: 1/100, Iteration: 168/438, Lr: 1e-05, Loss:11.13 (Coord:1.06 Conf:1.84 Cls:8.23)
# Train Epoch: 1/100, Iteration: 169/438, Lr: 1e-05, Loss:21.52 (Coord:2.33 Conf:4.08 Cls:15.11)
# Train Epoch: 1/100, Iteration: 170/438, Lr: 1e-05, Loss:21.48 (Coord:1.70 Conf:4.30 Cls:15.48)
# Train Epoch: 1/100, Iteration: 171/438, Lr: 1e-05, Loss:15.42 (Coord:1.73 Conf:2.09 Cls:11.60)
# Train Epoch: 1/100, Iteration: 172/438, Lr: 1e-05, Loss:9.97 (Coord:0.78 Conf:1.69 Cls:7.51)
# Train Epoch: 1/100, Iteration: 173/438, Lr: 1e-05, Loss:9.01 (Coord:0.55 Conf:2.04 Cls:6.43)
# Train Epoch: 1/100, Iteration: 174/438, Lr: 1e-05, Loss:17.56 (Coord:1.69 Conf:3.04 Cls:12.83)
# Train Epoch: 1/100, Iteration: 175/438, Lr: 1e-05, Loss:19.24 (Coord:1.55 Conf:4.45 Cls:13.24)
# Train Epoch: 1/100, Iteration: 176/438, Lr: 1e-05, Loss:15.91 (Coord:0.86 Conf:2.96 Cls:12.09)
# Train Epoch: 1/100, Iteration: 177/438, Lr: 1e-05, Loss:15.02 (Coord:0.89 Conf:2.92 Cls:11.20)
# Train Epoch: 1/100, Iteration: 178/438, Lr: 1e-05, Loss:18.57 (Coord:1.74 Conf:2.87 Cls:13.96)
# Train Epoch: 1/100, Iteration: 179/438, Lr: 1e-05, Loss:25.44 (Coord:1.94 Conf:4.08 Cls:19.42)
# Train Epoch: 1/100, Iteration: 180/438, Lr: 1e-05, Loss:17.34 (Coord:1.43 Conf:3.96 Cls:11.95)
# Train Epoch: 1/100, Iteration: 181/438, Lr: 1e-05, Loss:24.15 (Coord:2.24 Conf:4.32 Cls:17.60)
# Train Epoch: 1/100, Iteration: 182/438, Lr: 1e-05, Loss:16.06 (Coord:1.84 Conf:3.18 Cls:11.04)
# Train Epoch: 1/100, Iteration: 183/438, Lr: 1e-05, Loss:14.84 (Coord:1.10 Conf:2.85 Cls:10.88)
# Train Epoch: 1/100, Iteration: 184/438, Lr: 1e-05, Loss:25.82 (Coord:2.19 Conf:5.38 Cls:18.26)
# Train Epoch: 1/100, Iteration: 185/438, Lr: 1e-05, Loss:14.13 (Coord:1.22 Conf:3.36 Cls:9.54)
# Train Epoch: 1/100, Iteration: 186/438, Lr: 1e-05, Loss:16.21 (Coord:1.50 Conf:3.41 Cls:11.30)
# Train Epoch: 1/100, Iteration: 187/438, Lr: 1e-05, Loss:14.74 (Coord:1.43 Conf:2.75 Cls:10.55)
# Train Epoch: 1/100, Iteration: 188/438, Lr: 1e-05, Loss:17.89 (Coord:1.37 Conf:3.60 Cls:12.91)
# Train Epoch: 1/100, Iteration: 189/438, Lr: 1e-05, Loss:15.59 (Coord:1.43 Conf:2.71 Cls:11.45)
# Train Epoch: 1/100, Iteration: 190/438, Lr: 1e-05, Loss:13.46 (Coord:1.29 Conf:2.75 Cls:9.42)
# Train Epoch: 1/100, Iteration: 191/438, Lr: 1e-05, Loss:19.11 (Coord:2.12 Conf:3.12 Cls:13.87)
# Train Epoch: 1/100, Iteration: 192/438, Lr: 1e-05, Loss:9.78 (Coord:0.77 Conf:2.08 Cls:6.93)
# Train Epoch: 1/100, Iteration: 193/438, Lr: 1e-05, Loss:19.86 (Coord:2.14 Conf:3.35 Cls:14.36)
# Train Epoch: 1/100, Iteration: 194/438, Lr: 1e-05, Loss:25.54 (Coord:2.80 Conf:3.87 Cls:18.86)
# Train Epoch: 1/100, Iteration: 195/438, Lr: 1e-05, Loss:16.21 (Coord:1.89 Conf:3.58 Cls:10.73)
# Train Epoch: 1/100, Iteration: 196/438, Lr: 1e-05, Loss:16.04 (Coord:1.31 Conf:3.19 Cls:11.55)
# Train Epoch: 1/100, Iteration: 197/438, Lr: 1e-05, Loss:18.19 (Coord:1.64 Conf:3.98 Cls:12.58)
# Train Epoch: 1/100, Iteration: 198/438, Lr: 1e-05, Loss:18.19 (Coord:1.79 Conf:3.33 Cls:13.07)
# Train Epoch: 1/100, Iteration: 199/438, Lr: 1e-05, Loss:11.16 (Coord:0.92 Conf:2.35 Cls:7.89)
# Train Epoch: 1/100, Iteration: 200/438, Lr: 1e-05, Loss:16.55 (Coord:1.49 Conf:3.67 Cls:11.40)
# Train Epoch: 1/100, Iteration: 201/438, Lr: 1e-05, Loss:13.22 (Coord:1.38 Conf:2.54 Cls:9.31)
# Train Epoch: 1/100, Iteration: 202/438, Lr: 1e-05, Loss:21.37 (Coord:2.16 Conf:3.12 Cls:16.09)
# Train Epoch: 1/100, Iteration: 203/438, Lr: 1e-05, Loss:14.29 (Coord:1.54 Conf:2.99 Cls:9.76)
# Train Epoch: 1/100, Iteration: 204/438, Lr: 1e-05, Loss:13.39 (Coord:0.90 Conf:2.89 Cls:9.60)
# Train Epoch: 1/100, Iteration: 205/438, Lr: 1e-05, Loss:13.09 (Coord:1.28 Conf:2.37 Cls:9.43)
# Train Epoch: 1/100, Iteration: 206/438, Lr: 1e-05, Loss:15.82 (Coord:1.37 Conf:3.45 Cls:11.00)
# Train Epoch: 1/100, Iteration: 207/438, Lr: 1e-05, Loss:16.96 (Coord:1.05 Conf:3.85 Cls:12.06)
# Train Epoch: 1/100, Iteration: 208/438, Lr: 1e-05, Loss:21.42 (Coord:1.92 Conf:4.43 Cls:15.06)
# Train Epoch: 1/100, Iteration: 209/438, Lr: 1e-05, Loss:18.65 (Coord:1.59 Conf:3.57 Cls:13.49)
# Train Epoch: 1/100, Iteration: 210/438, Lr: 1e-05, Loss:22.27 (Coord:1.95 Conf:4.45 Cls:15.86)
# Train Epoch: 1/100, Iteration: 211/438, Lr: 1e-05, Loss:22.50 (Coord:1.74 Conf:4.75 Cls:16.00)
# Train Epoch: 1/100, Iteration: 212/438, Lr: 1e-05, Loss:11.26 (Coord:1.04 Conf:2.12 Cls:8.10)
# Train Epoch: 1/100, Iteration: 213/438, Lr: 1e-05, Loss:13.27 (Coord:0.88 Conf:2.20 Cls:10.19)
# Train Epoch: 1/100, Iteration: 214/438, Lr: 1e-05, Loss:20.27 (Coord:1.41 Conf:4.36 Cls:14.50)
# Train Epoch: 1/100, Iteration: 215/438, Lr: 1e-05, Loss:20.05 (Coord:1.72 Conf:3.29 Cls:15.03)
# Train Epoch: 1/100, Iteration: 216/438, Lr: 1e-05, Loss:15.10 (Coord:1.45 Conf:2.70 Cls:10.95)
# Train Epoch: 1/100, Iteration: 217/438, Lr: 1e-05, Loss:11.37 (Coord:0.70 Conf:2.76 Cls:7.91)
# Train Epoch: 1/100, Iteration: 218/438, Lr: 1e-05, Loss:21.81 (Coord:1.47 Conf:4.57 Cls:15.77)
# Train Epoch: 1/100, Iteration: 219/438, Lr: 1e-05, Loss:18.00 (Coord:1.74 Conf:2.51 Cls:13.75)
# Train Epoch: 1/100, Iteration: 220/438, Lr: 1e-05, Loss:10.06 (Coord:0.63 Conf:2.14 Cls:7.28)
# Train Epoch: 1/100, Iteration: 221/438, Lr: 1e-05, Loss:16.78 (Coord:1.12 Conf:3.79 Cls:11.87)
# Train Epoch: 1/100, Iteration: 222/438, Lr: 1e-05, Loss:33.81 (Coord:3.33 Conf:5.73 Cls:24.75)
# Train Epoch: 1/100, Iteration: 223/438, Lr: 1e-05, Loss:19.53 (Coord:2.11 Conf:3.53 Cls:13.89)
# Train Epoch: 1/100, Iteration: 224/438, Lr: 1e-05, Loss:10.12 (Coord:0.69 Conf:2.43 Cls:6.99)
# Train Epoch: 1/100, Iteration: 225/438, Lr: 1e-05, Loss:16.75 (Coord:1.32 Conf:3.67 Cls:11.75)
# Train Epoch: 1/100, Iteration: 226/438, Lr: 1e-05, Loss:15.89 (Coord:1.45 Conf:2.43 Cls:12.01)
# Train Epoch: 1/100, Iteration: 227/438, Lr: 1e-05, Loss:14.61 (Coord:1.00 Conf:3.57 Cls:10.04)
# Train Epoch: 1/100, Iteration: 228/438, Lr: 1e-05, Loss:17.08 (Coord:1.33 Conf:3.17 Cls:12.58)
# Train Epoch: 1/100, Iteration: 229/438, Lr: 1e-05, Loss:19.89 (Coord:2.45 Conf:3.06 Cls:14.38)
# Train Epoch: 1/100, Iteration: 230/438, Lr: 1e-05, Loss:21.26 (Coord:1.88 Conf:4.76 Cls:14.61)
# Train Epoch: 1/100, Iteration: 231/438, Lr: 1e-05, Loss:19.18 (Coord:1.69 Conf:4.47 Cls:13.02)
# Train Epoch: 1/100, Iteration: 232/438, Lr: 1e-05, Loss:11.52 (Coord:0.84 Conf:2.32 Cls:8.35)
# Train Epoch: 1/100, Iteration: 233/438, Lr: 1e-05, Loss:18.23 (Coord:1.39 Conf:3.43 Cls:13.40)
# Train Epoch: 1/100, Iteration: 234/438, Lr: 1e-05, Loss:28.79 (Coord:2.67 Conf:5.75 Cls:20.37)
# Train Epoch: 1/100, Iteration: 235/438, Lr: 1e-05, Loss:21.87 (Coord:2.01 Conf:2.64 Cls:17.21)
# Train Epoch: 1/100, Iteration: 236/438, Lr: 1e-05, Loss:11.57 (Coord:0.97 Conf:2.06 Cls:8.53)
# Train Epoch: 1/100, Iteration: 237/438, Lr: 1e-05, Loss:15.86 (Coord:1.54 Conf:2.42 Cls:11.90)
# Train Epoch: 1/100, Iteration: 238/438, Lr: 1e-05, Loss:16.93 (Coord:1.55 Conf:2.49 Cls:12.90)
# Train Epoch: 1/100, Iteration: 239/438, Lr: 1e-05, Loss:18.29 (Coord:1.13 Conf:4.89 Cls:12.27)
# Train Epoch: 1/100, Iteration: 240/438, Lr: 1e-05, Loss:15.21 (Coord:0.98 Conf:3.30 Cls:10.93)
# Train Epoch: 1/100, Iteration: 241/438, Lr: 1e-05, Loss:15.36 (Coord:0.99 Conf:2.79 Cls:11.58)
# Train Epoch: 1/100, Iteration: 242/438, Lr: 1e-05, Loss:23.17 (Coord:2.42 Conf:3.69 Cls:17.05)
# Train Epoch: 1/100, Iteration: 243/438, Lr: 1e-05, Loss:16.63 (Coord:2.00 Conf:2.55 Cls:12.08)
# Train Epoch: 1/100, Iteration: 244/438, Lr: 1e-05, Loss:16.24 (Coord:1.36 Conf:3.63 Cls:11.25)
# Train Epoch: 1/100, Iteration: 245/438, Lr: 1e-05, Loss:16.74 (Coord:1.39 Conf:2.92 Cls:12.43)
# Train Epoch: 1/100, Iteration: 246/438, Lr: 1e-05, Loss:14.18 (Coord:0.98 Conf:3.31 Cls:9.89)
# Train Epoch: 1/100, Iteration: 247/438, Lr: 1e-05, Loss:16.34 (Coord:1.49 Conf:2.20 Cls:12.65)
# Train Epoch: 1/100, Iteration: 248/438, Lr: 1e-05, Loss:18.67 (Coord:1.47 Conf:4.04 Cls:13.16)
# Train Epoch: 1/100, Iteration: 249/438, Lr: 1e-05, Loss:13.12 (Coord:0.98 Conf:2.79 Cls:9.34)
# Train Epoch: 1/100, Iteration: 250/438, Lr: 1e-05, Loss:23.83 (Coord:1.88 Conf:3.73 Cls:18.21)
# Train Epoch: 1/100, Iteration: 251/438, Lr: 1e-05, Loss:14.34 (Coord:1.21 Conf:1.95 Cls:11.18)
# Train Epoch: 1/100, Iteration: 252/438, Lr: 1e-05, Loss:14.28 (Coord:1.19 Conf:3.74 Cls:9.35)
# Train Epoch: 1/100, Iteration: 253/438, Lr: 1e-05, Loss:11.86 (Coord:0.51 Conf:3.02 Cls:8.33)
# Train Epoch: 1/100, Iteration: 254/438, Lr: 1e-05, Loss:16.20 (Coord:1.17 Conf:3.30 Cls:11.72)
# Train Epoch: 1/100, Iteration: 255/438, Lr: 1e-05, Loss:20.55 (Coord:1.48 Conf:4.64 Cls:14.42)
# Train Epoch: 1/100, Iteration: 256/438, Lr: 1e-05, Loss:14.04 (Coord:1.05 Conf:3.28 Cls:9.71)
# Train Epoch: 1/100, Iteration: 257/438, Lr: 1e-05, Loss:18.76 (Coord:1.73 Conf:3.98 Cls:13.05)
# Train Epoch: 1/100, Iteration: 258/438, Lr: 1e-05, Loss:21.00 (Coord:2.32 Conf:3.37 Cls:15.31)
# Train Epoch: 1/100, Iteration: 259/438, Lr: 1e-05, Loss:13.23 (Coord:0.86 Conf:3.33 Cls:9.04)
# Train Epoch: 1/100, Iteration: 260/438, Lr: 1e-05, Loss:22.24 (Coord:2.18 Conf:3.88 Cls:16.17)
# Train Epoch: 1/100, Iteration: 261/438, Lr: 1e-05, Loss:17.15 (Coord:1.00 Conf:4.09 Cls:12.06)
# Train Epoch: 1/100, Iteration: 262/438, Lr: 1e-05, Loss:17.51 (Coord:1.56 Conf:3.28 Cls:12.67)
# Train Epoch: 1/100, Iteration: 263/438, Lr: 1e-05, Loss:20.06 (Coord:1.49 Conf:3.62 Cls:14.96)
# Train Epoch: 1/100, Iteration: 264/438, Lr: 1e-05, Loss:14.37 (Coord:1.19 Conf:2.74 Cls:10.44)
# Train Epoch: 1/100, Iteration: 265/438, Lr: 1e-05, Loss:10.25 (Coord:0.50 Conf:2.79 Cls:6.96)
# Train Epoch: 1/100, Iteration: 266/438, Lr: 1e-05, Loss:11.08 (Coord:0.64 Conf:2.18 Cls:8.26)
# Train Epoch: 1/100, Iteration: 267/438, Lr: 1e-05, Loss:13.23 (Coord:1.07 Conf:2.60 Cls:9.56)
# Train Epoch: 1/100, Iteration: 268/438, Lr: 1e-05, Loss:19.13 (Coord:1.30 Conf:3.47 Cls:14.36)
# Train Epoch: 1/100, Iteration: 269/438, Lr: 1e-05, Loss:10.92 (Coord:0.77 Conf:2.33 Cls:7.82)
# Train Epoch: 1/100, Iteration: 270/438, Lr: 1e-05, Loss:12.14 (Coord:1.32 Conf:2.23 Cls:8.59)
# Train Epoch: 1/100, Iteration: 271/438, Lr: 1e-05, Loss:16.68 (Coord:1.37 Conf:2.73 Cls:12.58)
# Train Epoch: 1/100, Iteration: 272/438, Lr: 1e-05, Loss:18.25 (Coord:1.56 Conf:3.52 Cls:13.17)
# Train Epoch: 1/100, Iteration: 273/438, Lr: 1e-05, Loss:13.99 (Coord:1.22 Conf:2.68 Cls:10.08)
# Train Epoch: 1/100, Iteration: 274/438, Lr: 1e-05, Loss:16.58 (Coord:1.60 Conf:2.94 Cls:12.04)
# Train Epoch: 1/100, Iteration: 275/438, Lr: 1e-05, Loss:12.79 (Coord:0.95 Conf:3.27 Cls:8.57)
# Train Epoch: 1/100, Iteration: 276/438, Lr: 1e-05, Loss:12.12 (Coord:0.92 Conf:3.07 Cls:8.13)
# Train Epoch: 1/100, Iteration: 277/438, Lr: 1e-05, Loss:12.63 (Coord:0.77 Conf:2.61 Cls:9.25)
# Train Epoch: 1/100, Iteration: 278/438, Lr: 1e-05, Loss:16.99 (Coord:1.18 Conf:4.04 Cls:11.78)
# Train Epoch: 1/100, Iteration: 279/438, Lr: 1e-05, Loss:15.42 (Coord:1.43 Conf:2.51 Cls:11.48)
# Train Epoch: 1/100, Iteration: 280/438, Lr: 1e-05, Loss:16.55 (Coord:1.72 Conf:3.34 Cls:11.48)
# Train Epoch: 1/100, Iteration: 281/438, Lr: 1e-05, Loss:23.70 (Coord:1.39 Conf:4.74 Cls:17.58)
# Train Epoch: 1/100, Iteration: 282/438, Lr: 1e-05, Loss:13.39 (Coord:1.66 Conf:1.72 Cls:10.01)
# Train Epoch: 1/100, Iteration: 283/438, Lr: 1e-05, Loss:21.40 (Coord:1.99 Conf:4.53 Cls:14.88)
# Train Epoch: 1/100, Iteration: 284/438, Lr: 1e-05, Loss:12.21 (Coord:1.05 Conf:2.29 Cls:8.87)
# Train Epoch: 1/100, Iteration: 285/438, Lr: 1e-05, Loss:24.30 (Coord:2.81 Conf:4.37 Cls:17.12)
# Train Epoch: 1/100, Iteration: 286/438, Lr: 1e-05, Loss:18.28 (Coord:1.22 Conf:3.64 Cls:13.42)
# Train Epoch: 1/100, Iteration: 287/438, Lr: 1e-05, Loss:10.21 (Coord:1.02 Conf:1.89 Cls:7.31)
# Train Epoch: 1/100, Iteration: 288/438, Lr: 1e-05, Loss:16.56 (Coord:1.27 Conf:4.02 Cls:11.28)
# Train Epoch: 1/100, Iteration: 289/438, Lr: 1e-05, Loss:17.78 (Coord:1.25 Conf:3.27 Cls:13.25)
# Train Epoch: 1/100, Iteration: 290/438, Lr: 1e-05, Loss:16.84 (Coord:1.88 Conf:3.41 Cls:11.55)
# Train Epoch: 1/100, Iteration: 291/438, Lr: 1e-05, Loss:12.15 (Coord:1.28 Conf:2.77 Cls:8.10)
# Train Epoch: 1/100, Iteration: 292/438, Lr: 1e-05, Loss:12.86 (Coord:1.21 Conf:2.39 Cls:9.26)
# Train Epoch: 1/100, Iteration: 293/438, Lr: 1e-05, Loss:13.82 (Coord:1.06 Conf:3.52 Cls:9.24)
# Train Epoch: 1/100, Iteration: 294/438, Lr: 1e-05, Loss:17.22 (Coord:0.98 Conf:5.03 Cls:11.22)
# Train Epoch: 1/100, Iteration: 295/438, Lr: 1e-05, Loss:17.01 (Coord:1.31 Conf:2.74 Cls:12.97)
# Train Epoch: 1/100, Iteration: 296/438, Lr: 1e-05, Loss:12.60 (Coord:1.42 Conf:3.40 Cls:7.78)
# Train Epoch: 1/100, Iteration: 297/438, Lr: 1e-05, Loss:17.93 (Coord:1.39 Conf:3.94 Cls:12.61)
# Train Epoch: 1/100, Iteration: 298/438, Lr: 1e-05, Loss:18.83 (Coord:2.15 Conf:3.40 Cls:13.28)
# Train Epoch: 1/100, Iteration: 299/438, Lr: 1e-05, Loss:17.44 (Coord:1.46 Conf:3.61 Cls:12.38)
# Train Epoch: 1/100, Iteration: 300/438, Lr: 1e-05, Loss:23.50 (Coord:2.21 Conf:4.88 Cls:16.41)
# Train Epoch: 1/100, Iteration: 301/438, Lr: 1e-05, Loss:14.26 (Coord:1.06 Conf:3.38 Cls:9.81)
# Train Epoch: 1/100, Iteration: 302/438, Lr: 1e-05, Loss:26.95 (Coord:2.50 Conf:5.10 Cls:19.35)
# Train Epoch: 1/100, Iteration: 303/438, Lr: 1e-05, Loss:27.43 (Coord:2.64 Conf:4.42 Cls:20.38)
# Train Epoch: 1/100, Iteration: 304/438, Lr: 1e-05, Loss:18.35 (Coord:1.45 Conf:3.84 Cls:13.06)
# Train Epoch: 1/100, Iteration: 305/438, Lr: 1e-05, Loss:17.28 (Coord:1.70 Conf:3.01 Cls:12.57)
# Train Epoch: 1/100, Iteration: 306/438, Lr: 1e-05, Loss:15.60 (Coord:1.17 Conf:3.21 Cls:11.23)
# Train Epoch: 1/100, Iteration: 307/438, Lr: 1e-05, Loss:30.43 (Coord:3.30 Conf:6.17 Cls:20.96)
# Train Epoch: 1/100, Iteration: 308/438, Lr: 1e-05, Loss:14.21 (Coord:0.98 Conf:3.62 Cls:9.61)
# Train Epoch: 1/100, Iteration: 309/438, Lr: 1e-05, Loss:23.19 (Coord:1.99 Conf:4.45 Cls:16.74)
# Train Epoch: 1/100, Iteration: 310/438, Lr: 1e-05, Loss:17.92 (Coord:1.68 Conf:4.20 Cls:12.04)
# Train Epoch: 1/100, Iteration: 311/438, Lr: 1e-05, Loss:27.94 (Coord:1.69 Conf:6.15 Cls:20.10)
# Train Epoch: 1/100, Iteration: 312/438, Lr: 1e-05, Loss:13.31 (Coord:1.05 Conf:2.58 Cls:9.68)
# Train Epoch: 1/100, Iteration: 313/438, Lr: 1e-05, Loss:20.50 (Coord:2.02 Conf:3.78 Cls:14.70)
# Train Epoch: 1/100, Iteration: 314/438, Lr: 1e-05, Loss:11.31 (Coord:0.86 Conf:2.26 Cls:8.18)
# Train Epoch: 1/100, Iteration: 315/438, Lr: 1e-05, Loss:18.93 (Coord:1.62 Conf:4.04 Cls:13.27)
# Train Epoch: 1/100, Iteration: 316/438, Lr: 1e-05, Loss:26.35 (Coord:1.81 Conf:5.83 Cls:18.70)
# Train Epoch: 1/100, Iteration: 317/438, Lr: 1e-05, Loss:11.66 (Coord:1.04 Conf:2.32 Cls:8.29)
# Train Epoch: 1/100, Iteration: 318/438, Lr: 1e-05, Loss:25.26 (Coord:2.88 Conf:4.52 Cls:17.86)
# Train Epoch: 1/100, Iteration: 319/438, Lr: 1e-05, Loss:20.18 (Coord:1.40 Conf:4.60 Cls:14.18)
# Train Epoch: 1/100, Iteration: 320/438, Lr: 1e-05, Loss:13.88 (Coord:1.14 Conf:2.62 Cls:10.12)
# Train Epoch: 1/100, Iteration: 321/438, Lr: 1e-05, Loss:14.78 (Coord:1.23 Conf:3.16 Cls:10.39)
# Train Epoch: 1/100, Iteration: 322/438, Lr: 1e-05, Loss:19.68 (Coord:1.75 Conf:3.34 Cls:14.59)
# Train Epoch: 1/100, Iteration: 323/438, Lr: 1e-05, Loss:24.99 (Coord:1.73 Conf:4.76 Cls:18.50)
# Train Epoch: 1/100, Iteration: 324/438, Lr: 1e-05, Loss:32.24 (Coord:2.62 Conf:5.25 Cls:24.38)
# Train Epoch: 1/100, Iteration: 325/438, Lr: 1e-05, Loss:10.50 (Coord:0.43 Conf:3.08 Cls:6.99)
# Train Epoch: 1/100, Iteration: 326/438, Lr: 1e-05, Loss:15.74 (Coord:1.37 Conf:2.32 Cls:12.05)
# Train Epoch: 1/100, Iteration: 327/438, Lr: 1e-05, Loss:22.36 (Coord:2.16 Conf:4.43 Cls:15.76)
# Train Epoch: 1/100, Iteration: 328/438, Lr: 1e-05, Loss:17.46 (Coord:1.53 Conf:3.49 Cls:12.45)
# Train Epoch: 1/100, Iteration: 329/438, Lr: 1e-05, Loss:18.42 (Coord:1.84 Conf:3.80 Cls:12.78)
# Train Epoch: 1/100, Iteration: 330/438, Lr: 1e-05, Loss:11.30 (Coord:0.78 Conf:2.52 Cls:8.00)
# Train Epoch: 1/100, Iteration: 331/438, Lr: 1e-05, Loss:15.59 (Coord:1.18 Conf:2.78 Cls:11.63)
# Train Epoch: 1/100, Iteration: 332/438, Lr: 1e-05, Loss:13.43 (Coord:1.12 Conf:2.65 Cls:9.66)
# Train Epoch: 1/100, Iteration: 333/438, Lr: 1e-05, Loss:13.40 (Coord:0.98 Conf:2.06 Cls:10.37)
# Train Epoch: 1/100, Iteration: 334/438, Lr: 1e-05, Loss:13.93 (Coord:1.07 Conf:3.39 Cls:9.47)
# Train Epoch: 1/100, Iteration: 335/438, Lr: 1e-05, Loss:13.32 (Coord:0.99 Conf:2.70 Cls:9.63)
# Train Epoch: 1/100, Iteration: 336/438, Lr: 1e-05, Loss:13.40 (Coord:1.10 Conf:3.11 Cls:9.19)
# Train Epoch: 1/100, Iteration: 337/438, Lr: 1e-05, Loss:12.95 (Coord:1.13 Conf:3.10 Cls:8.73)
# Train Epoch: 1/100, Iteration: 338/438, Lr: 1e-05, Loss:12.12 (Coord:1.02 Conf:2.10 Cls:9.00)
# Train Epoch: 1/100, Iteration: 339/438, Lr: 1e-05, Loss:18.40 (Coord:1.33 Conf:4.03 Cls:13.05)
# Train Epoch: 1/100, Iteration: 340/438, Lr: 1e-05, Loss:13.50 (Coord:1.27 Conf:3.00 Cls:9.24)
# Train Epoch: 1/100, Iteration: 341/438, Lr: 1e-05, Loss:21.32 (Coord:2.20 Conf:2.96 Cls:16.16)
# Train Epoch: 1/100, Iteration: 342/438, Lr: 1e-05, Loss:18.05 (Coord:1.58 Conf:3.77 Cls:12.70)
# Train Epoch: 1/100, Iteration: 343/438, Lr: 1e-05, Loss:11.40 (Coord:0.97 Conf:2.70 Cls:7.72)
# Train Epoch: 1/100, Iteration: 344/438, Lr: 1e-05, Loss:12.99 (Coord:0.77 Conf:3.20 Cls:9.02)
# Train Epoch: 1/100, Iteration: 345/438, Lr: 1e-05, Loss:16.37 (Coord:1.05 Conf:3.15 Cls:12.17)
# Train Epoch: 1/100, Iteration: 346/438, Lr: 1e-05, Loss:21.66 (Coord:1.71 Conf:3.42 Cls:16.53)
# Train Epoch: 1/100, Iteration: 347/438, Lr: 1e-05, Loss:17.05 (Coord:1.82 Conf:3.16 Cls:12.07)
# Train Epoch: 1/100, Iteration: 348/438, Lr: 1e-05, Loss:18.27 (Coord:0.95 Conf:3.37 Cls:13.94)
# Train Epoch: 1/100, Iteration: 349/438, Lr: 1e-05, Loss:28.29 (Coord:2.18 Conf:5.66 Cls:20.46)
# Train Epoch: 1/100, Iteration: 350/438, Lr: 1e-05, Loss:13.64 (Coord:1.07 Conf:2.38 Cls:10.20)
# Train Epoch: 1/100, Iteration: 351/438, Lr: 1e-05, Loss:16.58 (Coord:1.30 Conf:3.52 Cls:11.76)
# Train Epoch: 1/100, Iteration: 352/438, Lr: 1e-05, Loss:23.15 (Coord:2.46 Conf:4.27 Cls:16.42)
# Train Epoch: 1/100, Iteration: 353/438, Lr: 1e-05, Loss:11.99 (Coord:1.20 Conf:2.70 Cls:8.09)
# Train Epoch: 1/100, Iteration: 354/438, Lr: 1e-05, Loss:17.20 (Coord:1.47 Conf:3.52 Cls:12.22)
# Train Epoch: 1/100, Iteration: 355/438, Lr: 1e-05, Loss:13.19 (Coord:1.16 Conf:2.96 Cls:9.07)
# Train Epoch: 1/100, Iteration: 356/438, Lr: 1e-05, Loss:23.25 (Coord:1.99 Conf:4.35 Cls:16.91)
# Train Epoch: 1/100, Iteration: 357/438, Lr: 1e-05, Loss:15.64 (Coord:0.79 Conf:3.23 Cls:11.62)
# Train Epoch: 1/100, Iteration: 358/438, Lr: 1e-05, Loss:16.25 (Coord:1.12 Conf:3.99 Cls:11.14)
# Train Epoch: 1/100, Iteration: 359/438, Lr: 1e-05, Loss:11.83 (Coord:1.21 Conf:2.16 Cls:8.46)
# Train Epoch: 1/100, Iteration: 360/438, Lr: 1e-05, Loss:15.23 (Coord:1.02 Conf:3.46 Cls:10.75)
# Train Epoch: 1/100, Iteration: 361/438, Lr: 1e-05, Loss:13.76 (Coord:0.90 Conf:2.63 Cls:10.24)
# Train Epoch: 1/100, Iteration: 362/438, Lr: 1e-05, Loss:11.79 (Coord:0.89 Conf:2.79 Cls:8.10)
# Train Epoch: 1/100, Iteration: 363/438, Lr: 1e-05, Loss:14.37 (Coord:1.09 Conf:3.20 Cls:10.08)
# Train Epoch: 1/100, Iteration: 364/438, Lr: 1e-05, Loss:19.05 (Coord:1.40 Conf:3.55 Cls:14.10)
# Train Epoch: 1/100, Iteration: 365/438, Lr: 1e-05, Loss:13.38 (Coord:0.57 Conf:3.76 Cls:9.05)
# Train Epoch: 1/100, Iteration: 366/438, Lr: 1e-05, Loss:16.99 (Coord:1.46 Conf:2.41 Cls:13.12)
# Train Epoch: 1/100, Iteration: 367/438, Lr: 1e-05, Loss:14.59 (Coord:1.10 Conf:2.13 Cls:11.37)
# Train Epoch: 1/100, Iteration: 368/438, Lr: 1e-05, Loss:11.60 (Coord:1.61 Conf:2.92 Cls:7.07)
# Train Epoch: 1/100, Iteration: 369/438, Lr: 1e-05, Loss:21.23 (Coord:1.65 Conf:3.42 Cls:16.16)
# Train Epoch: 1/100, Iteration: 370/438, Lr: 1e-05, Loss:11.17 (Coord:0.83 Conf:2.00 Cls:8.34)
# Train Epoch: 1/100, Iteration: 371/438, Lr: 1e-05, Loss:14.25 (Coord:1.30 Conf:3.42 Cls:9.53)
# Train Epoch: 1/100, Iteration: 372/438, Lr: 1e-05, Loss:10.17 (Coord:0.77 Conf:2.39 Cls:7.02)
# Train Epoch: 1/100, Iteration: 373/438, Lr: 1e-05, Loss:12.52 (Coord:1.01 Conf:3.03 Cls:8.49)
# Train Epoch: 1/100, Iteration: 374/438, Lr: 1e-05, Loss:13.88 (Coord:1.15 Conf:2.68 Cls:10.06)
# Train Epoch: 1/100, Iteration: 375/438, Lr: 1e-05, Loss:12.38 (Coord:1.06 Conf:2.14 Cls:9.18)
# Train Epoch: 1/100, Iteration: 376/438, Lr: 1e-05, Loss:16.34 (Coord:1.21 Conf:3.05 Cls:12.09)
# Train Epoch: 1/100, Iteration: 377/438, Lr: 1e-05, Loss:49.55 (Coord:4.90 Conf:5.98 Cls:38.67)
# Train Epoch: 1/100, Iteration: 378/438, Lr: 1e-05, Loss:11.72 (Coord:1.11 Conf:2.52 Cls:8.09)
# Train Epoch: 1/100, Iteration: 379/438, Lr: 1e-05, Loss:10.48 (Coord:0.57 Conf:2.44 Cls:7.47)
# Train Epoch: 1/100, Iteration: 380/438, Lr: 1e-05, Loss:9.63 (Coord:0.86 Conf:1.74 Cls:7.02)
# Train Epoch: 1/100, Iteration: 381/438, Lr: 1e-05, Loss:15.43 (Coord:1.19 Conf:3.11 Cls:11.14)
# Train Epoch: 1/100, Iteration: 382/438, Lr: 1e-05, Loss:12.30 (Coord:0.81 Conf:3.79 Cls:7.70)
# Train Epoch: 1/100, Iteration: 383/438, Lr: 1e-05, Loss:18.79 (Coord:1.14 Conf:3.99 Cls:13.66)
# Train Epoch: 1/100, Iteration: 384/438, Lr: 1e-05, Loss:10.52 (Coord:0.89 Conf:2.00 Cls:7.63)
# Train Epoch: 1/100, Iteration: 385/438, Lr: 1e-05, Loss:22.90 (Coord:2.79 Conf:3.59 Cls:16.53)
# Train Epoch: 1/100, Iteration: 386/438, Lr: 1e-05, Loss:11.63 (Coord:1.18 Conf:2.73 Cls:7.72)
# Train Epoch: 1/100, Iteration: 387/438, Lr: 1e-05, Loss:11.69 (Coord:1.13 Conf:2.69 Cls:7.88)
# Train Epoch: 1/100, Iteration: 388/438, Lr: 1e-05, Loss:10.89 (Coord:0.78 Conf:2.90 Cls:7.21)
# Train Epoch: 1/100, Iteration: 389/438, Lr: 1e-05, Loss:17.93 (Coord:1.42 Conf:4.42 Cls:12.09)
# Train Epoch: 1/100, Iteration: 390/438, Lr: 1e-05, Loss:14.13 (Coord:0.94 Conf:2.72 Cls:10.47)
# Train Epoch: 1/100, Iteration: 391/438, Lr: 1e-05, Loss:33.49 (Coord:3.04 Conf:8.03 Cls:22.42)
# Train Epoch: 1/100, Iteration: 392/438, Lr: 1e-05, Loss:16.33 (Coord:1.31 Conf:3.18 Cls:11.84)
# Train Epoch: 1/100, Iteration: 393/438, Lr: 1e-05, Loss:16.14 (Coord:0.93 Conf:4.08 Cls:11.13)
# Train Epoch: 1/100, Iteration: 394/438, Lr: 1e-05, Loss:10.83 (Coord:1.03 Conf:2.00 Cls:7.81)
# Train Epoch: 1/100, Iteration: 395/438, Lr: 1e-05, Loss:10.10 (Coord:0.65 Conf:2.08 Cls:7.37)
# Train Epoch: 1/100, Iteration: 396/438, Lr: 1e-05, Loss:11.79 (Coord:1.18 Conf:2.94 Cls:7.67)
# Train Epoch: 1/100, Iteration: 397/438, Lr: 1e-05, Loss:16.27 (Coord:1.61 Conf:3.26 Cls:11.39)
# Train Epoch: 1/100, Iteration: 398/438, Lr: 1e-05, Loss:15.11 (Coord:1.61 Conf:2.96 Cls:10.54)
# Train Epoch: 1/100, Iteration: 399/438, Lr: 1e-05, Loss:12.29 (Coord:0.66 Conf:3.03 Cls:8.60)
# Train Epoch: 1/100, Iteration: 400/438, Lr: 1e-05, Loss:11.23 (Coord:0.79 Conf:2.59 Cls:7.84)
# Train Epoch: 1/100, Iteration: 401/438, Lr: 1e-05, Loss:21.73 (Coord:1.84 Conf:3.09 Cls:16.80)
# Train Epoch: 1/100, Iteration: 402/438, Lr: 1e-05, Loss:11.25 (Coord:0.73 Conf:2.68 Cls:7.85)
# Train Epoch: 1/100, Iteration: 403/438, Lr: 1e-05, Loss:14.14 (Coord:0.72 Conf:3.27 Cls:10.15)
# Train Epoch: 1/100, Iteration: 404/438, Lr: 1e-05, Loss:21.48 (Coord:1.73 Conf:5.15 Cls:14.60)
# Train Epoch: 1/100, Iteration: 405/438, Lr: 1e-05, Loss:25.36 (Coord:2.74 Conf:3.36 Cls:19.26)
# Train Epoch: 1/100, Iteration: 406/438, Lr: 1e-05, Loss:19.60 (Coord:1.60 Conf:3.60 Cls:14.40)
# Train Epoch: 1/100, Iteration: 407/438, Lr: 1e-05, Loss:21.63 (Coord:3.30 Conf:3.74 Cls:14.59)
# Train Epoch: 1/100, Iteration: 408/438, Lr: 1e-05, Loss:17.87 (Coord:1.46 Conf:4.35 Cls:12.06)
# Train Epoch: 1/100, Iteration: 409/438, Lr: 1e-05, Loss:16.63 (Coord:1.27 Conf:3.53 Cls:11.84)
# Train Epoch: 1/100, Iteration: 410/438, Lr: 1e-05, Loss:14.95 (Coord:0.84 Conf:2.57 Cls:11.54)
# Train Epoch: 1/100, Iteration: 411/438, Lr: 1e-05, Loss:17.13 (Coord:0.62 Conf:3.90 Cls:12.61)
# Train Epoch: 1/100, Iteration: 412/438, Lr: 1e-05, Loss:22.55 (Coord:1.25 Conf:5.56 Cls:15.73)
# Train Epoch: 1/100, Iteration: 413/438, Lr: 1e-05, Loss:19.37 (Coord:1.68 Conf:2.91 Cls:14.78)
# Train Epoch: 1/100, Iteration: 414/438, Lr: 1e-05, Loss:28.50 (Coord:2.30 Conf:5.69 Cls:20.52)
# Train Epoch: 1/100, Iteration: 415/438, Lr: 1e-05, Loss:15.69 (Coord:0.94 Conf:2.70 Cls:12.05)
# Train Epoch: 1/100, Iteration: 416/438, Lr: 1e-05, Loss:14.26 (Coord:0.84 Conf:3.06 Cls:10.37)
# Train Epoch: 1/100, Iteration: 417/438, Lr: 1e-05, Loss:19.12 (Coord:1.96 Conf:3.80 Cls:13.35)
# Train Epoch: 1/100, Iteration: 418/438, Lr: 1e-05, Loss:10.04 (Coord:1.06 Conf:2.67 Cls:6.31)
# Train Epoch: 1/100, Iteration: 419/438, Lr: 1e-05, Loss:14.66 (Coord:1.32 Conf:3.33 Cls:10.01)
# Train Epoch: 1/100, Iteration: 420/438, Lr: 1e-05, Loss:21.96 (Coord:2.03 Conf:5.43 Cls:14.50)
# Train Epoch: 1/100, Iteration: 421/438, Lr: 1e-05, Loss:14.13 (Coord:1.20 Conf:2.55 Cls:10.38)
# Train Epoch: 1/100, Iteration: 422/438, Lr: 1e-05, Loss:18.55 (Coord:2.19 Conf:3.46 Cls:12.90)
# Train Epoch: 1/100, Iteration: 423/438, Lr: 1e-05, Loss:14.79 (Coord:2.23 Conf:2.52 Cls:10.03)
# Train Epoch: 1/100, Iteration: 424/438, Lr: 1e-05, Loss:15.63 (Coord:1.68 Conf:3.19 Cls:10.76)
# Train Epoch: 1/100, Iteration: 425/438, Lr: 1e-05, Loss:17.77 (Coord:0.95 Conf:4.15 Cls:12.68)
# Train Epoch: 1/100, Iteration: 426/438, Lr: 1e-05, Loss:14.86 (Coord:1.42 Conf:3.07 Cls:10.37)
# Train Epoch: 1/100, Iteration: 427/438, Lr: 1e-05, Loss:18.48 (Coord:1.16 Conf:4.22 Cls:13.10)
# Train Epoch: 1/100, Iteration: 428/438, Lr: 1e-05, Loss:16.41 (Coord:1.48 Conf:3.05 Cls:11.88)
# Train Epoch: 1/100, Iteration: 429/438, Lr: 1e-05, Loss:14.87 (Coord:1.11 Conf:3.33 Cls:10.44)
# Train Epoch: 1/100, Iteration: 430/438, Lr: 1e-05, Loss:28.16 (Coord:2.73 Conf:5.82 Cls:19.61)
# Train Epoch: 1/100, Iteration: 431/438, Lr: 1e-05, Loss:19.85 (Coord:1.34 Conf:5.13 Cls:13.38)
# Train Epoch: 1/100, Iteration: 432/438, Lr: 1e-05, Loss:13.70 (Coord:1.07 Conf:3.35 Cls:9.29)
# Train Epoch: 1/100, Iteration: 433/438, Lr: 1e-05, Loss:13.30 (Coord:1.16 Conf:3.80 Cls:8.35)
# Train Epoch: 1/100, Iteration: 434/438, Lr: 1e-05, Loss:20.03 (Coord:1.71 Conf:2.63 Cls:15.68)
# Train Epoch: 1/100, Iteration: 435/438, Lr: 1e-05, Loss:20.17 (Coord:2.21 Conf:3.35 Cls:14.61)
# Train Epoch: 1/100, Iteration: 436/438, Lr: 1e-05, Loss:18.66 (Coord:1.66 Conf:3.94 Cls:13.06)
# Train Epoch: 1/100, Iteration: 437/438, Lr: 1e-05, Loss:15.07 (Coord:1.46 Conf:2.57 Cls:11.03)
# Train Epoch: 1/100, Iteration: 438/438, Lr: 1e-05, Loss:14.25 (Coord:0.79 Conf:3.64 Cls:9.82)
#
# Test Epoch: 1/100, Lr: 1e-05, Loss:15.66 (Coord:1.29 Conf:3.26 Cls:11.11)
#
# Train Epoch: 2/100, Iteration: 1/438, Lr: 1e-05, Loss:16.02 (Coord:1.11 Conf:3.50 Cls:11.41)
# Train Epoch: 2/100, Iteration: 2/438, Lr: 1e-05, Loss:11.90 (Coord:1.53 Conf:2.36 Cls:8.01)
# Train Epoch: 2/100, Iteration: 3/438, Lr: 1e-05, Loss:11.59 (Coord:0.81 Conf:2.37 Cls:8.40)
# Train Epoch: 2/100, Iteration: 4/438, Lr: 1e-05, Loss:14.56 (Coord:1.10 Conf:2.76 Cls:10.70)
# Train Epoch: 2/100, Iteration: 5/438, Lr: 1e-05, Loss:21.48 (Coord:2.62 Conf:5.14 Cls:13.72)
# Train Epoch: 2/100, Iteration: 6/438, Lr: 1e-05, Loss:12.37 (Coord:0.91 Conf:2.38 Cls:9.08)
# Train Epoch: 2/100, Iteration: 7/438, Lr: 1e-05, Loss:12.04 (Coord:0.85 Conf:2.96 Cls:8.24)
# Train Epoch: 2/100, Iteration: 8/438, Lr: 1e-05, Loss:16.92 (Coord:1.25 Conf:2.70 Cls:12.97)
# Train Epoch: 2/100, Iteration: 9/438, Lr: 1e-05, Loss:16.73 (Coord:1.47 Conf:3.72 Cls:11.55)
# Train Epoch: 2/100, Iteration: 10/438, Lr: 1e-05, Loss:16.95 (Coord:1.71 Conf:3.68 Cls:11.55)
# Train Epoch: 2/100, Iteration: 11/438, Lr: 1e-05, Loss:13.33 (Coord:1.05 Conf:3.09 Cls:9.18)
# Train Epoch: 2/100, Iteration: 12/438, Lr: 1e-05, Loss:15.60 (Coord:1.27 Conf:3.42 Cls:10.90)
# Train Epoch: 2/100, Iteration: 13/438, Lr: 1e-05, Loss:21.51 (Coord:1.82 Conf:5.23 Cls:14.46)
# Train Epoch: 2/100, Iteration: 14/438, Lr: 1e-05, Loss:13.13 (Coord:1.17 Conf:2.66 Cls:9.30)
# Train Epoch: 2/100, Iteration: 15/438, Lr: 1e-05, Loss:18.89 (Coord:1.76 Conf:3.90 Cls:13.22)
# Train Epoch: 2/100, Iteration: 16/438, Lr: 1e-05, Loss:14.59 (Coord:0.99 Conf:3.56 Cls:10.04)
# Train Epoch: 2/100, Iteration: 17/438, Lr: 1e-05, Loss:9.50 (Coord:0.78 Conf:2.13 Cls:6.58)
# Train Epoch: 2/100, Iteration: 18/438, Lr: 1e-05, Loss:20.95 (Coord:1.69 Conf:3.82 Cls:15.44)
# Train Epoch: 2/100, Iteration: 19/438, Lr: 1e-05, Loss:12.88 (Coord:0.96 Conf:2.05 Cls:9.87)
# Train Epoch: 2/100, Iteration: 20/438, Lr: 1e-05, Loss:15.66 (Coord:0.94 Conf:2.98 Cls:11.74)
# Train Epoch: 2/100, Iteration: 21/438, Lr: 1e-05, Loss:12.10 (Coord:0.84 Conf:3.13 Cls:8.14)
# Train Epoch: 2/100, Iteration: 22/438, Lr: 1e-05, Loss:15.77 (Coord:1.39 Conf:3.13 Cls:11.25)
# Train Epoch: 2/100, Iteration: 23/438, Lr: 1e-05, Loss:23.96 (Coord:2.40 Conf:3.71 Cls:17.84)
# Train Epoch: 2/100, Iteration: 24/438, Lr: 1e-05, Loss:21.42 (Coord:1.80 Conf:3.64 Cls:15.98)
# Train Epoch: 2/100, Iteration: 25/438, Lr: 1e-05, Loss:20.80 (Coord:2.84 Conf:5.25 Cls:12.71)
# Train Epoch: 2/100, Iteration: 26/438, Lr: 1e-05, Loss:15.59 (Coord:1.53 Conf:2.18 Cls:11.88)
# Train Epoch: 2/100, Iteration: 27/438, Lr: 1e-05, Loss:17.48 (Coord:1.65 Conf:3.62 Cls:12.21)
# Train Epoch: 2/100, Iteration: 28/438, Lr: 1e-05, Loss:20.25 (Coord:1.80 Conf:3.51 Cls:14.94)
# Train Epoch: 2/100, Iteration: 29/438, Lr: 1e-05, Loss:11.09 (Coord:0.94 Conf:1.82 Cls:8.34)
# Train Epoch: 2/100, Iteration: 30/438, Lr: 1e-05, Loss:13.16 (Coord:1.04 Conf:3.21 Cls:8.91)
# Train Epoch: 2/100, Iteration: 31/438, Lr: 1e-05, Loss:16.59 (Coord:1.12 Conf:3.03 Cls:12.45)
# Train Epoch: 2/100, Iteration: 32/438, Lr: 1e-05, Loss:20.44 (Coord:2.32 Conf:4.00 Cls:14.12)
# Train Epoch: 2/100, Iteration: 33/438, Lr: 1e-05, Loss:22.98 (Coord:1.59 Conf:4.87 Cls:16.52)
# Train Epoch: 2/100, Iteration: 34/438, Lr: 1e-05, Loss:16.94 (Coord:2.02 Conf:3.80 Cls:11.12)
# Train Epoch: 2/100, Iteration: 35/438, Lr: 1e-05, Loss:18.88 (Coord:1.57 Conf:2.79 Cls:14.52)
# Train Epoch: 2/100, Iteration: 36/438, Lr: 1e-05, Loss:12.22 (Coord:1.37 Conf:2.19 Cls:8.66)
# Train Epoch: 2/100, Iteration: 37/438, Lr: 1e-05, Loss:13.18 (Coord:0.77 Conf:3.26 Cls:9.15)
# Train Epoch: 2/100, Iteration: 38/438, Lr: 1e-05, Loss:19.61 (Coord:2.29 Conf:4.22 Cls:13.09)
# Train Epoch: 2/100, Iteration: 39/438, Lr: 1e-05, Loss:28.94 (Coord:2.00 Conf:6.43 Cls:20.51)
# Train Epoch: 2/100, Iteration: 40/438, Lr: 1e-05, Loss:25.70 (Coord:2.39 Conf:5.29 Cls:18.02)
# Train Epoch: 2/100, Iteration: 41/438, Lr: 1e-05, Loss:17.98 (Coord:1.32 Conf:4.32 Cls:12.34)
# Train Epoch: 2/100, Iteration: 42/438, Lr: 1e-05, Loss:14.82 (Coord:1.23 Conf:2.99 Cls:10.60)
# Train Epoch: 2/100, Iteration: 43/438, Lr: 1e-05, Loss:16.87 (Coord:1.02 Conf:4.46 Cls:11.38)
# Train Epoch: 2/100, Iteration: 44/438, Lr: 1e-05, Loss:12.81 (Coord:1.05 Conf:2.38 Cls:9.39)
# Train Epoch: 2/100, Iteration: 45/438, Lr: 1e-05, Loss:14.04 (Coord:0.66 Conf:3.80 Cls:9.59)
# Train Epoch: 2/100, Iteration: 46/438, Lr: 1e-05, Loss:11.61 (Coord:0.89 Conf:2.38 Cls:8.35)
# Train Epoch: 2/100, Iteration: 47/438, Lr: 1e-05, Loss:14.47 (Coord:1.27 Conf:3.57 Cls:9.63)
# Train Epoch: 2/100, Iteration: 48/438, Lr: 1e-05, Loss:12.23 (Coord:1.07 Conf:2.77 Cls:8.39)
# Train Epoch: 2/100, Iteration: 49/438, Lr: 1e-05, Loss:15.96 (Coord:1.70 Conf:4.63 Cls:9.64)
# Train Epoch: 2/100, Iteration: 50/438, Lr: 1e-05, Loss:11.26 (Coord:0.83 Conf:2.60 Cls:7.83)
# Train Epoch: 2/100, Iteration: 51/438, Lr: 1e-05, Loss:14.28 (Coord:1.23 Conf:4.13 Cls:8.92)
# Train Epoch: 2/100, Iteration: 52/438, Lr: 1e-05, Loss:13.86 (Coord:0.89 Conf:3.94 Cls:9.03)
# Train Epoch: 2/100, Iteration: 53/438, Lr: 1e-05, Loss:21.58 (Coord:1.67 Conf:4.08 Cls:15.83)
# Train Epoch: 2/100, Iteration: 54/438, Lr: 1e-05, Loss:13.52 (Coord:0.83 Conf:2.87 Cls:9.82)
# Train Epoch: 2/100, Iteration: 55/438, Lr: 1e-05, Loss:18.84 (Coord:1.19 Conf:3.62 Cls:14.03)
# Train Epoch: 2/100, Iteration: 56/438, Lr: 1e-05, Loss:21.16 (Coord:2.00 Conf:3.73 Cls:15.44)
# Train Epoch: 2/100, Iteration: 57/438, Lr: 1e-05, Loss:15.42 (Coord:0.89 Conf:3.46 Cls:11.07)
# Train Epoch: 2/100, Iteration: 58/438, Lr: 1e-05, Loss:11.36 (Coord:1.12 Conf:2.24 Cls:7.99)
# Train Epoch: 2/100, Iteration: 59/438, Lr: 1e-05, Loss:16.09 (Coord:0.88 Conf:3.61 Cls:11.60)
# Train Epoch: 2/100, Iteration: 60/438, Lr: 1e-05, Loss:12.40 (Coord:1.24 Conf:2.08 Cls:9.08)
# ...
# Train Epoch: 44/100, Iteration: 273/438, Lr: 0.0001, Loss:2.25 (Coord:0.40 Conf:1.65 Cls:0.20)
# Train Epoch: 44/100, Iteration: 274/438, Lr: 0.0001, Loss:2.43 (Coord:0.37 Conf:1.96 Cls:0.11)
# Train Epoch: 44/100, Iteration: 275/438, Lr: 0.0001, Loss:3.77 (Coord:0.60 Conf:2.98 Cls:0.18)
# Train Epoch: 44/100, Iteration: 276/438, Lr: 0.0001, Loss:3.89 (Coord:0.40 Conf:3.32 Cls:0.18)
# Train Epoch: 44/100, Iteration: 277/438, Lr: 0.0001, Loss:1.70 (Coord:0.19 Conf:1.41 Cls:0.10)
# Train Epoch: 44/100, Iteration: 278/438, Lr: 0.0001, Loss:2.72 (Coord:0.29 Conf:2.37 Cls:0.06)
# Train Epoch: 44/100, Iteration: 279/438, Lr: 0.0001, Loss:1.70 (Coord:0.29 Conf:1.37 Cls:0.04)
# Train Epoch: 44/100, Iteration: 280/438, Lr: 0.0001, Loss:1.36 (Coord:0.29 Conf:1.04 Cls:0.03)
# Train Epoch: 44/100, Iteration: 281/438, Lr: 0.0001, Loss:3.48 (Coord:0.59 Conf:2.69 Cls:0.20)
# Train Epoch: 44/100, Iteration: 282/438, Lr: 0.0001, Loss:4.59 (Coord:0.39 Conf:3.94 Cls:0.26)
# Train Epoch: 44/100, Iteration: 283/438, Lr: 0.0001, Loss:1.04 (Coord:0.21 Conf:0.79 Cls:0.04)
# Train Epoch: 44/100, Iteration: 284/438, Lr: 0.0001, Loss:3.14 (Coord:0.63 Conf:2.42 Cls:0.10)
# Train Epoch: 44/100, Iteration: 285/438, Lr: 0.0001, Loss:2.08 (Coord:0.30 Conf:1.66 Cls:0.13)
# Train Epoch: 44/100, Iteration: 286/438, Lr: 0.0001, Loss:3.34 (Coord:0.27 Conf:2.34 Cls:0.73)
# Train Epoch: 44/100, Iteration: 287/438, Lr: 0.0001, Loss:3.01 (Coord:0.45 Conf:2.49 Cls:0.08)
# Train Epoch: 44/100, Iteration: 288/438, Lr: 0.0001, Loss:1.55 (Coord:0.22 Conf:1.28 Cls:0.06)
# Train Epoch: 44/100, Iteration: 289/438, Lr: 0.0001, Loss:2.02 (Coord:0.31 Conf:1.66 Cls:0.05)
# Train Epoch: 44/100, Iteration: 290/438, Lr: 0.0001, Loss:3.17 (Coord:0.49 Conf:2.35 Cls:0.33)
# Train Epoch: 44/100, Iteration: 291/438, Lr: 0.0001, Loss:2.60 (Coord:0.24 Conf:2.23 Cls:0.13)
# Train Epoch: 44/100, Iteration: 292/438, Lr: 0.0001, Loss:4.96 (Coord:0.40 Conf:4.34 Cls:0.22)
# Train Epoch: 44/100, Iteration: 293/438, Lr: 0.0001, Loss:2.03 (Coord:0.31 Conf:1.53 Cls:0.18)
# Train Epoch: 44/100, Iteration: 294/438, Lr: 0.0001, Loss:1.64 (Coord:0.26 Conf:1.30 Cls:0.08)
# Train Epoch: 44/100, Iteration: 295/438, Lr: 0.0001, Loss:4.33 (Coord:0.77 Conf:2.18 Cls:1.38)
# Train Epoch: 44/100, Iteration: 296/438, Lr: 0.0001, Loss:3.05 (Coord:0.44 Conf:2.44 Cls:0.17)
# Train Epoch: 44/100, Iteration: 297/438, Lr: 0.0001, Loss:3.25 (Coord:0.56 Conf:2.29 Cls:0.40)
# Train Epoch: 44/100, Iteration: 298/438, Lr: 0.0001, Loss:1.65 (Coord:0.11 Conf:1.51 Cls:0.02)
# Train Epoch: 44/100, Iteration: 299/438, Lr: 0.0001, Loss:2.06 (Coord:0.36 Conf:1.44 Cls:0.26)
# Train Epoch: 44/100, Iteration: 300/438, Lr: 0.0001, Loss:3.30 (Coord:0.43 Conf:2.31 Cls:0.56)
# Train Epoch: 44/100, Iteration: 301/438, Lr: 0.0001, Loss:3.73 (Coord:0.46 Conf:3.03 Cls:0.24)
# Train Epoch: 44/100, Iteration: 302/438, Lr: 0.0001, Loss:6.24 (Coord:0.46 Conf:4.44 Cls:1.34)
# Train Epoch: 44/100, Iteration: 303/438, Lr: 0.0001, Loss:1.45 (Coord:0.20 Conf:1.15 Cls:0.11)
# Train Epoch: 44/100, Iteration: 304/438, Lr: 0.0001, Loss:2.45 (Coord:0.46 Conf:1.89 Cls:0.10)
# Train Epoch: 44/100, Iteration: 305/438, Lr: 0.0001, Loss:3.34 (Coord:0.35 Conf:2.93 Cls:0.06)
# Train Epoch: 44/100, Iteration: 306/438, Lr: 0.0001, Loss:1.26 (Coord:0.25 Conf:0.95 Cls:0.05)
# Train Epoch: 44/100, Iteration: 307/438, Lr: 0.0001, Loss:3.49 (Coord:0.39 Conf:2.95 Cls:0.15)
# Train Epoch: 44/100, Iteration: 308/438, Lr: 0.0001, Loss:3.25 (Coord:0.34 Conf:2.60 Cls:0.32)
# Train Epoch: 44/100, Iteration: 309/438, Lr: 0.0001, Loss:2.24 (Coord:0.22 Conf:1.71 Cls:0.32)
# Train Epoch: 44/100, Iteration: 310/438, Lr: 0.0001, Loss:2.21 (Coord:0.30 Conf:1.67 Cls:0.23)
# Train Epoch: 44/100, Iteration: 311/438, Lr: 0.0001, Loss:1.84 (Coord:0.27 Conf:1.49 Cls:0.08)
# Train Epoch: 44/100, Iteration: 312/438, Lr: 0.0001, Loss:3.42 (Coord:0.67 Conf:2.68 Cls:0.07)
# Train Epoch: 44/100, Iteration: 313/438, Lr: 0.0001, Loss:2.32 (Coord:0.27 Conf:1.74 Cls:0.31)
# Train Epoch: 44/100, Iteration: 314/438, Lr: 0.0001, Loss:1.95 (Coord:0.33 Conf:1.51 Cls:0.11)
# Train Epoch: 44/100, Iteration: 315/438, Lr: 0.0001, Loss:2.92 (Coord:0.46 Conf:2.16 Cls:0.30)
# Train Epoch: 44/100, Iteration: 316/438, Lr: 0.0001, Loss:3.22 (Coord:0.46 Conf:2.56 Cls:0.19)
# Train Epoch: 44/100, Iteration: 317/438, Lr: 0.0001, Loss:3.28 (Coord:0.69 Conf:2.39 Cls:0.21)
# Train Epoch: 44/100, Iteration: 318/438, Lr: 0.0001, Loss:2.04 (Coord:0.35 Conf:1.53 Cls:0.16)
# Train Epoch: 44/100, Iteration: 319/438, Lr: 0.0001, Loss:4.29 (Coord:0.55 Conf:3.13 Cls:0.61)
# Train Epoch: 44/100, Iteration: 320/438, Lr: 0.0001, Loss:2.33 (Coord:0.38 Conf:1.89 Cls:0.06)
# Train Epoch: 44/100, Iteration: 321/438, Lr: 0.0001, Loss:2.00 (Coord:0.43 Conf:1.48 Cls:0.09)
# Train Epoch: 44/100, Iteration: 322/438, Lr: 0.0001, Loss:2.01 (Coord:0.20 Conf:1.12 Cls:0.69)
# Train Epoch: 44/100, Iteration: 323/438, Lr: 0.0001, Loss:3.10 (Coord:0.27 Conf:2.73 Cls:0.11)
# Train Epoch: 44/100, Iteration: 324/438, Lr: 0.0001, Loss:2.57 (Coord:0.39 Conf:1.89 Cls:0.28)
# Train Epoch: 44/100, Iteration: 325/438, Lr: 0.0001, Loss:4.76 (Coord:0.96 Conf:3.61 Cls:0.19)
# Train Epoch: 44/100, Iteration: 326/438, Lr: 0.0001, Loss:3.81 (Coord:0.34 Conf:3.23 Cls:0.24)
# Train Epoch: 44/100, Iteration: 327/438, Lr: 0.0001, Loss:2.07 (Coord:0.29 Conf:1.51 Cls:0.27)
# Train Epoch: 44/100, Iteration: 328/438, Lr: 0.0001, Loss:1.54 (Coord:0.30 Conf:1.13 Cls:0.11)
# Train Epoch: 44/100, Iteration: 329/438, Lr: 0.0001, Loss:4.33 (Coord:0.78 Conf:3.38 Cls:0.17)
# Train Epoch: 44/100, Iteration: 330/438, Lr: 0.0001, Loss:1.78 (Coord:0.27 Conf:1.28 Cls:0.23)
# Train Epoch: 44/100, Iteration: 331/438, Lr: 0.0001, Loss:2.76 (Coord:0.33 Conf:2.22 Cls:0.21)
# Train Epoch: 44/100, Iteration: 332/438, Lr: 0.0001, Loss:3.18 (Coord:0.49 Conf:2.39 Cls:0.29)
# Train Epoch: 44/100, Iteration: 333/438, Lr: 0.0001, Loss:1.69 (Coord:0.31 Conf:1.32 Cls:0.06)
# Train Epoch: 44/100, Iteration: 334/438, Lr: 0.0001, Loss:3.56 (Coord:0.53 Conf:2.59 Cls:0.43)
# Train Epoch: 44/100, Iteration: 335/438, Lr: 0.0001, Loss:3.26 (Coord:0.36 Conf:2.81 Cls:0.08)
# Train Epoch: 44/100, Iteration: 336/438, Lr: 0.0001, Loss:1.71 (Coord:0.36 Conf:1.33 Cls:0.03)
# Train Epoch: 44/100, Iteration: 337/438, Lr: 0.0001, Loss:2.88 (Coord:0.33 Conf:2.35 Cls:0.20)
# Train Epoch: 44/100, Iteration: 338/438, Lr: 0.0001, Loss:3.10 (Coord:0.54 Conf:2.37 Cls:0.20)
# Train Epoch: 44/100, Iteration: 339/438, Lr: 0.0001, Loss:2.48 (Coord:0.48 Conf:1.92 Cls:0.09)
# Train Epoch: 44/100, Iteration: 340/438, Lr: 0.0001, Loss:5.57 (Coord:0.90 Conf:4.31 Cls:0.35)
# Train Epoch: 44/100, Iteration: 341/438, Lr: 0.0001, Loss:2.53 (Coord:0.35 Conf:2.01 Cls:0.17)
# Train Epoch: 44/100, Iteration: 342/438, Lr: 0.0001, Loss:2.47 (Coord:0.26 Conf:2.03 Cls:0.18)
# Train Epoch: 44/100, Iteration: 343/438, Lr: 0.0001, Loss:2.27 (Coord:0.26 Conf:1.96 Cls:0.06)
# Train Epoch: 44/100, Iteration: 344/438, Lr: 0.0001, Loss:2.41 (Coord:0.41 Conf:1.61 Cls:0.39)
# Train Epoch: 44/100, Iteration: 345/438, Lr: 0.0001, Loss:2.47 (Coord:0.34 Conf:1.90 Cls:0.23)
# Train Epoch: 44/100, Iteration: 346/438, Lr: 0.0001, Loss:4.16 (Coord:0.77 Conf:3.14 Cls:0.25)
# Train Epoch: 44/100, Iteration: 347/438, Lr: 0.0001, Loss:3.79 (Coord:0.61 Conf:2.53 Cls:0.64)
# Train Epoch: 44/100, Iteration: 348/438, Lr: 0.0001, Loss:1.93 (Coord:0.33 Conf:1.53 Cls:0.07)
# Train Epoch: 44/100, Iteration: 349/438, Lr: 0.0001, Loss:2.22 (Coord:0.22 Conf:1.83 Cls:0.17)
# Train Epoch: 44/100, Iteration: 350/438, Lr: 0.0001, Loss:3.18 (Coord:0.32 Conf:2.56 Cls:0.31)
# Train Epoch: 44/100, Iteration: 351/438, Lr: 0.0001, Loss:3.99 (Coord:0.32 Conf:3.47 Cls:0.20)
# Train Epoch: 44/100, Iteration: 352/438, Lr: 0.0001, Loss:2.54 (Coord:0.48 Conf:1.79 Cls:0.27)
# Train Epoch: 44/100, Iteration: 353/438, Lr: 0.0001, Loss:1.78 (Coord:0.29 Conf:1.45 Cls:0.04)
# Train Epoch: 44/100, Iteration: 354/438, Lr: 0.0001, Loss:2.47 (Coord:0.50 Conf:1.91 Cls:0.06)
# Train Epoch: 44/100, Iteration: 355/438, Lr: 0.0001, Loss:2.64 (Coord:0.36 Conf:2.09 Cls:0.19)
# Train Epoch: 44/100, Iteration: 356/438, Lr: 0.0001, Loss:2.68 (Coord:0.30 Conf:2.29 Cls:0.10)
# Train Epoch: 44/100, Iteration: 357/438, Lr: 0.0001, Loss:3.33 (Coord:0.49 Conf:2.74 Cls:0.11)
# Train Epoch: 44/100, Iteration: 358/438, Lr: 0.0001, Loss:1.89 (Coord:0.28 Conf:1.44 Cls:0.16)
# Train Epoch: 44/100, Iteration: 359/438, Lr: 0.0001, Loss:1.12 (Coord:0.17 Conf:0.92 Cls:0.03)
# Train Epoch: 44/100, Iteration: 360/438, Lr: 0.0001, Loss:2.10 (Coord:0.28 Conf:1.75 Cls:0.07)
# Train Epoch: 44/100, Iteration: 361/438, Lr: 0.0001, Loss:2.59 (Coord:0.30 Conf:2.27 Cls:0.02)
# Train Epoch: 44/100, Iteration: 362/438, Lr: 0.0001, Loss:3.45 (Coord:0.30 Conf:2.30 Cls:0.85)
# Train Epoch: 44/100, Iteration: 363/438, Lr: 0.0001, Loss:2.56 (Coord:0.46 Conf:1.92 Cls:0.19)
# Train Epoch: 44/100, Iteration: 364/438, Lr: 0.0001, Loss:4.28 (Coord:0.69 Conf:2.20 Cls:1.39)
# Train Epoch: 44/100, Iteration: 365/438, Lr: 0.0001, Loss:3.74 (Coord:0.63 Conf:2.63 Cls:0.47)
# Train Epoch: 44/100, Iteration: 366/438, Lr: 0.0001, Loss:2.09 (Coord:0.45 Conf:1.55 Cls:0.09)
# Train Epoch: 44/100, Iteration: 367/438, Lr: 0.0001, Loss:2.21 (Coord:0.37 Conf:1.73 Cls:0.12)
# Train Epoch: 44/100, Iteration: 368/438, Lr: 0.0001, Loss:3.08 (Coord:0.46 Conf:2.52 Cls:0.10)
# Train Epoch: 44/100, Iteration: 369/438, Lr: 0.0001, Loss:2.34 (Coord:0.36 Conf:1.88 Cls:0.11)
# Train Epoch: 44/100, Iteration: 370/438, Lr: 0.0001, Loss:2.54 (Coord:0.53 Conf:1.91 Cls:0.09)
# Train Epoch: 44/100, Iteration: 371/438, Lr: 0.0001, Loss:3.40 (Coord:0.84 Conf:2.33 Cls:0.23)
# Train Epoch: 44/100, Iteration: 372/438, Lr: 0.0001, Loss:1.29 (Coord:0.20 Conf:0.98 Cls:0.11)
# Train Epoch: 44/100, Iteration: 373/438, Lr: 0.0001, Loss:2.61 (Coord:0.65 Conf:1.89 Cls:0.07)
# Train Epoch: 44/100, Iteration: 374/438, Lr: 0.0001, Loss:2.04 (Coord:0.24 Conf:1.77 Cls:0.03)
# Train Epoch: 44/100, Iteration: 375/438, Lr: 0.0001, Loss:3.03 (Coord:0.35 Conf:2.57 Cls:0.11)
# Train Epoch: 44/100, Iteration: 376/438, Lr: 0.0001, Loss:2.67 (Coord:0.53 Conf:1.56 Cls:0.58)
# Train Epoch: 44/100, Iteration: 377/438, Lr: 0.0001, Loss:2.86 (Coord:0.61 Conf:2.03 Cls:0.21)
# Train Epoch: 44/100, Iteration: 378/438, Lr: 0.0001, Loss:2.82 (Coord:0.30 Conf:2.20 Cls:0.33)
# Train Epoch: 44/100, Iteration: 379/438, Lr: 0.0001, Loss:2.05 (Coord:0.30 Conf:1.43 Cls:0.33)
# Train Epoch: 44/100, Iteration: 380/438, Lr: 0.0001, Loss:2.67 (Coord:0.65 Conf:1.90 Cls:0.12)
# Train Epoch: 44/100, Iteration: 381/438, Lr: 0.0001, Loss:2.97 (Coord:0.53 Conf:1.92 Cls:0.52)
# Train Epoch: 44/100, Iteration: 382/438, Lr: 0.0001, Loss:2.25 (Coord:0.44 Conf:1.50 Cls:0.32)
# Train Epoch: 44/100, Iteration: 383/438, Lr: 0.0001, Loss:3.07 (Coord:0.39 Conf:2.60 Cls:0.09)
# Train Epoch: 44/100, Iteration: 384/438, Lr: 0.0001, Loss:2.39 (Coord:0.30 Conf:1.83 Cls:0.26)
# Train Epoch: 44/100, Iteration: 385/438, Lr: 0.0001, Loss:1.49 (Coord:0.28 Conf:1.15 Cls:0.07)
# Train Epoch: 44/100, Iteration: 386/438, Lr: 0.0001, Loss:2.11 (Coord:0.55 Conf:1.35 Cls:0.21)
# Train Epoch: 44/100, Iteration: 387/438, Lr: 0.0001, Loss:2.98 (Coord:0.50 Conf:2.23 Cls:0.25)
# Train Epoch: 44/100, Iteration: 388/438, Lr: 0.0001, Loss:1.20 (Coord:0.28 Conf:0.82 Cls:0.09)
# Train Epoch: 44/100, Iteration: 389/438, Lr: 0.0001, Loss:2.80 (Coord:0.46 Conf:2.19 Cls:0.15)
# Train Epoch: 44/100, Iteration: 390/438, Lr: 0.0001, Loss:1.76 (Coord:0.28 Conf:1.37 Cls:0.11)
# Train Epoch: 44/100, Iteration: 391/438, Lr: 0.0001, Loss:3.97 (Coord:0.51 Conf:3.13 Cls:0.33)
# Train Epoch: 44/100, Iteration: 392/438, Lr: 0.0001, Loss:2.33 (Coord:0.34 Conf:1.93 Cls:0.06)
# Train Epoch: 44/100, Iteration: 393/438, Lr: 0.0001, Loss:1.91 (Coord:0.25 Conf:1.48 Cls:0.18)
# Train Epoch: 44/100, Iteration: 394/438, Lr: 0.0001, Loss:1.72 (Coord:0.18 Conf:1.40 Cls:0.14)
# Train Epoch: 44/100, Iteration: 395/438, Lr: 0.0001, Loss:2.66 (Coord:0.55 Conf:1.92 Cls:0.19)
# Train Epoch: 44/100, Iteration: 396/438, Lr: 0.0001, Loss:4.63 (Coord:0.79 Conf:3.38 Cls:0.45)
# Train Epoch: 44/100, Iteration: 397/438, Lr: 0.0001, Loss:2.02 (Coord:0.50 Conf:1.40 Cls:0.13)
# Train Epoch: 44/100, Iteration: 398/438, Lr: 0.0001, Loss:3.28 (Coord:0.46 Conf:2.73 Cls:0.08)
# Train Epoch: 44/100, Iteration: 399/438, Lr: 0.0001, Loss:1.51 (Coord:0.35 Conf:1.12 Cls:0.03)
# Train Epoch: 44/100, Iteration: 400/438, Lr: 0.0001, Loss:2.10 (Coord:0.22 Conf:1.68 Cls:0.20)
# Train Epoch: 44/100, Iteration: 401/438, Lr: 0.0001, Loss:2.18 (Coord:0.24 Conf:1.76 Cls:0.19)
# Train Epoch: 44/100, Iteration: 402/438, Lr: 0.0001, Loss:2.97 (Coord:0.37 Conf:2.36 Cls:0.25)
# Train Epoch: 44/100, Iteration: 403/438, Lr: 0.0001, Loss:1.25 (Coord:0.23 Conf:0.90 Cls:0.13)
# Train Epoch: 44/100, Iteration: 404/438, Lr: 0.0001, Loss:2.62 (Coord:0.45 Conf:1.99 Cls:0.19)
# Train Epoch: 44/100, Iteration: 405/438, Lr: 0.0001, Loss:2.76 (Coord:0.40 Conf:2.29 Cls:0.07)
# Train Epoch: 44/100, Iteration: 406/438, Lr: 0.0001, Loss:1.93 (Coord:0.25 Conf:1.47 Cls:0.21)
# Train Epoch: 44/100, Iteration: 407/438, Lr: 0.0001, Loss:3.64 (Coord:0.75 Conf:2.59 Cls:0.31)
# Train Epoch: 44/100, Iteration: 408/438, Lr: 0.0001, Loss:2.89 (Coord:0.48 Conf:1.91 Cls:0.50)
# Train Epoch: 44/100, Iteration: 409/438, Lr: 0.0001, Loss:3.17 (Coord:0.42 Conf:2.42 Cls:0.33)
# Train Epoch: 44/100, Iteration: 410/438, Lr: 0.0001, Loss:4.28 (Coord:0.46 Conf:2.23 Cls:1.59)
# Train Epoch: 44/100, Iteration: 411/438, Lr: 0.0001, Loss:1.41 (Coord:0.36 Conf:1.03 Cls:0.03)
# Train Epoch: 44/100, Iteration: 412/438, Lr: 0.0001, Loss:1.84 (Coord:0.31 Conf:1.45 Cls:0.08)
# Train Epoch: 44/100, Iteration: 413/438, Lr: 0.0001, Loss:2.91 (Coord:0.24 Conf:2.55 Cls:0.12)
# Train Epoch: 44/100, Iteration: 414/438, Lr: 0.0001, Loss:3.97 (Coord:0.91 Conf:2.88 Cls:0.18)
# Train Epoch: 44/100, Iteration: 415/438, Lr: 0.0001, Loss:1.72 (Coord:0.47 Conf:1.18 Cls:0.07)
# Train Epoch: 44/100, Iteration: 416/438, Lr: 0.0001, Loss:1.80 (Coord:0.45 Conf:1.11 Cls:0.23)
# Train Epoch: 44/100, Iteration: 417/438, Lr: 0.0001, Loss:1.59 (Coord:0.27 Conf:0.95 Cls:0.36)
# Train Epoch: 44/100, Iteration: 418/438, Lr: 0.0001, Loss:1.74 (Coord:0.22 Conf:1.48 Cls:0.05)
# Train Epoch: 44/100, Iteration: 419/438, Lr: 0.0001, Loss:2.42 (Coord:0.27 Conf:2.03 Cls:0.11)
# Train Epoch: 44/100, Iteration: 420/438, Lr: 0.0001, Loss:2.02 (Coord:0.45 Conf:1.44 Cls:0.12)
# Train Epoch: 44/100, Iteration: 421/438, Lr: 0.0001, Loss:1.94 (Coord:0.27 Conf:1.58 Cls:0.09)
# Train Epoch: 44/100, Iteration: 422/438, Lr: 0.0001, Loss:2.85 (Coord:0.25 Conf:0.88 Cls:1.73)
# Train Epoch: 44/100, Iteration: 423/438, Lr: 0.0001, Loss:3.64 (Coord:0.47 Conf:2.96 Cls:0.21)
# Train Epoch: 44/100, Iteration: 424/438, Lr: 0.0001, Loss:1.68 (Coord:0.25 Conf:1.37 Cls:0.05)
# Train Epoch: 44/100, Iteration: 425/438, Lr: 0.0001, Loss:3.58 (Coord:0.55 Conf:2.26 Cls:0.76)
# Train Epoch: 44/100, Iteration: 426/438, Lr: 0.0001, Loss:1.02 (Coord:0.21 Conf:0.75 Cls:0.05)
# Train Epoch: 44/100, Iteration: 427/438, Lr: 0.0001, Loss:4.70 (Coord:0.47 Conf:3.96 Cls:0.26)
# Train Epoch: 44/100, Iteration: 428/438, Lr: 0.0001, Loss:1.91 (Coord:0.22 Conf:1.52 Cls:0.18)
# Train Epoch: 44/100, Iteration: 429/438, Lr: 0.0001, Loss:3.01 (Coord:0.47 Conf:1.95 Cls:0.59)
# Train Epoch: 44/100, Iteration: 430/438, Lr: 0.0001, Loss:3.72 (Coord:0.45 Conf:3.17 Cls:0.10)
# Train Epoch: 44/100, Iteration: 431/438, Lr: 0.0001, Loss:2.68 (Coord:0.61 Conf:1.92 Cls:0.15)
# Train Epoch: 44/100, Iteration: 432/438, Lr: 0.0001, Loss:2.53 (Coord:0.46 Conf:1.97 Cls:0.10)
# Train Epoch: 44/100, Iteration: 433/438, Lr: 0.0001, Loss:3.77 (Coord:0.39 Conf:3.00 Cls:0.38)
# Train Epoch: 44/100, Iteration: 434/438, Lr: 0.0001, Loss:4.40 (Coord:0.70 Conf:3.24 Cls:0.46)
# Train Epoch: 44/100, Iteration: 435/438, Lr: 0.0001, Loss:3.16 (Coord:0.38 Conf:2.39 Cls:0.39)
# Train Epoch: 44/100, Iteration: 436/438, Lr: 0.0001, Loss:1.49 (Coord:0.21 Conf:1.26 Cls:0.02)
# Train Epoch: 44/100, Iteration: 437/438, Lr: 0.0001, Loss:1.91 (Coord:0.33 Conf:1.53 Cls:0.05)
# Train Epoch: 44/100, Iteration: 438/438, Lr: 0.0001, Loss:3.07 (Coord:0.48 Conf:2.31 Cls:0.27)
#
# Test Epoch: 44/100, Lr: 0.0001, Loss:11.59 (Coord:0.62 Conf:4.02 Cls:6.94)
#
# Stop training at epoch 43. The lowest loss achieved is 11.59229850769043

# %%
15.66 (Coord:1.30 Conf:3.28 Cls:11.08)
15.38 (Coord:0.77 Conf:3.91 Cls:10.70)
